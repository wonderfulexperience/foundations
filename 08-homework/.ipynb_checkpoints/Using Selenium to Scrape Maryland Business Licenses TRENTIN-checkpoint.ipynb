# %% [markdown]
# # Scraping Maryland Business Licenses with Selenium
#
# Maryland has a [great portal](https://jportal.mdcourts.gov/license/pbPublicSearch.jsp) for searching business licenses, but the only problem is you have to check a box in order to get in.
#
# 1. Try to visit [the public search page](https://jportal.mdcourts.gov/license/pbPublicSearch.jsp)
# 2. Get redirected to a "I agree to this" page. Click that you've read the disclaimer, click Enter the Site.
# 3. Click "Search License Records" down at the bottom of the page
# 4. You're now on the search page! From the "Jurisdiction" dropdown, select "Statewide"
# 5. In the "Trade Name" field, type "Vap%" to try to find vape shops
# 6. Click "Next" in the bottom right-hand corner to go to the next page
# 7. Click "Click for detail" to see the details for a specific business license.
#
# That's a lot of stuff! **Let's get to work.**

# %% [markdown]
# ## Preparation
#
# ### When you search for a business license, what URL should Selenium try to visit first?

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
driver = webdriver.Chrome()

# %%
#starting with the disclaimer
url = "https://jportal.mdcourts.gov/license/index_disclaimer.jsp"
driver.get(url)

# %% [markdown]
# **It isn't going to work, though! It's going to redirect to that intro page.** You can use *Incognito mode* to go back through the "Check the box, etc" series of pages.
#
# ### How will you identify the checkbox to check it?
#
# Selenium can find elements by:
#
# - name
# - Class
# - ID
# - CSS selector (**ASK ME WHAT THIS IS** if you don't know)
# - XPath (**ASK ME WHAT THIS IS** because you definitely don't know)
# - Link text
# - Partial link text
#
# So in other words, what's unique about this element?
#
# - *TIP: I have a secret awesome way to do this, but you have to ask.*

# %%
#using XPath for the checkbox
checkbox = driver.find_element_by_xpath('//*[@id="checkbox"]')
checkbox.click()

# %% [markdown]
# ### How will you identify the button to select it, or the form to submit it?
#
# Selenium can submit forms by either
#
# - Selecting the form and using `.submit()`, or
# - Selecting the button and using `.click()`
#
# You only need to be able to get **one, not both.**

# %%
# using XPath to identify button
button = driver.find_element_by_xpath('/html/body/table/tbody/tr[7]/td/form/div/input[2]')
button.click()

# %% [markdown]
# ### Once you're on the next page, how will you click the "SEARCH LICENSE RECORDS" link or follow its URL?

# %%
# using XPath to identify "search"-link
link = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[6]/td[2]/a[2]')
link.click()

# %% [markdown]
# ### Now you're on the form page. How do you pick "Statewide" for the jurisdiction dropdown?

# %%
from selenium.webdriver.support.ui import Select
dropdown = driver.find_element_by_xpath('//*[@id="slcJurisdiction"]')
select = Select(dropdown)
select.select_by_visible_text("Statewide")

# %% [markdown]
# ### How do you type "vap%" into the Trade Name field?

# %%
# tradeName.send_keys("vap%")

# %% [markdown]
# ### How do you click the submit button or submit the form?

# %%
# searchButton = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/form/table/tbody/tr[14]/td/input[1]')
# searchButton.click()

# %% [markdown]
# ### How can you find and click the 'Next' button on the search results page?

# %%
# nextButton = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[2]/tbody/tr/td[3]/a/nobr')
# nextButton.click()

# %% [markdown]
# # Okay, let's scrape!
#
# ### Use Selenium to search for vape shops statewide, and then click through until it reaches the last page.
#
# Don't scrape yet!

# %%
from selenium.webdriver.support.ui import Select
dropdown = driver.find_element_by_xpath('//*[@id="slcJurisdiction"]')
select = Select(dropdown)
select.select_by_visible_text("Statewide")
tradeName = driver.find_element_by_xpath('//*[@id="txtTradeName"]')
tradeName.send_keys("vap%")
searchButton = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/form/table/tbody/tr[14]/td/input[1]')
searchButton.click()

# %% [markdown]
# ### Use Selenium to scrape the first page of search results for vape shops statewide (well, we'll try).
#
# - *TIP: You can find elements/text using Selenium, or use BeautifulSoup with `doc = BeautifulSoup(driver.page_source)`*
#
# I've included some BeautifulSoup code that might be helpful. If you use it, **ask me how I made it.** It's important.

# %%
from bs4 import BeautifulSoup
doc = BeautifulSoup(driver.page_source, "html.parser")
business_headers = doc.find_all('tr',class_='searchfieldtitle')

# %%
list_companies = []
for header in business_headers:
    company = {}
    rows = header.find_next_siblings('tr')
    company['trade_name'] = header.find_all('td')[1].text.strip()
    company['company_name'] = rows[0].find_all('td')[1].text.strip()
    company['city_name'] = rows[2].find_all('td')[1].text.strip()
    company['address'] = rows[1].find_all('td')[1].text.strip()
    company['county'] = rows[3].find_all('td')[1].text.strip()
    company_url = header.find_all('td')[2].find('a', href=True)
    if company_url:
        company['detail_link'] = 'https://jportal.mdcourts.gov/license/'+company_url['href']
    else:
        company['detail_link'] = ''
        
    #check if there's a license number (no number when status is pending)    
    license_number = rows[1].find_all('td')[2].find('span')
    
    if license_number:
        company['license_status'] = rows[0].find_all('td')[2].find('span').next_sibling.strip()
        company['license_number'] = license_number.next_sibling.strip()
        company['issue_date'] = rows[2].find_all('td')[2].find('span').next_sibling.strip()
    else:
        company['license_status'] = rows[0].find_all('td')[2].find('span').next_sibling.strip()
        company['license_number'] = ""
        company['issue_date'] = ""
    list_companies.append(company)

# %% [markdown]
# ### Save these into `vape-results.csv`

# %%
import pandas as pd
df = pd.DataFrame(list_companies)
df.to_csv('vape_results.csv',index=False)

# %% [markdown]
# ### Open `vape-results.csv` to make sure there aren't any extra weird columns

# %%
df = pd.read_csv('vape_results.csv')
df
# Out:
#                         address               city_name  \
# 0  1724 N SALISBURY BLVD UNIT 2     SALISBURY, MD 21801
# 1         1015 S SALISBURY BLVD     SALISBURY, MD 21801
# 2       2299 JOHNS HOPKINS ROAD     GAMBRILLS, MD 21054
# 3               110 S. PINEY RD       CHESTER, MD 21619
# 4           346 RITCHIE HIGHWAY  SEVERNA PARK, MD 21146
#
#                 company_name               county  \
# 0                AMIN NARGIS      Wicomico County
# 1                AMIN NARGIS      Wicomico County
# 2      ANJ DISTRIBUTIONS LLC  Anne Arundel County
# 3  COX TRADING COMPANY L L C  Queen Anne's County
# 4            COX TRADING LLC  Anne Arundel County
#
#                                          detail_link issue_date  \
# 0  https://jportal.mdcourts.gov/license/pbLicense...  4/27/2017
# 1  https://jportal.mdcourts.gov/license/pbLicense...  4/27/2017
# 2  https://jportal.mdcourts.gov/license/pbLicense...  4/05/2017
# 3  https://jportal.mdcourts.gov/license/pbLicense...  5/31/2017
# 4                                                NaN        NaN
#
#    license_number license_status        trade_name
# 0      22173807.0         Issued   VAPE IT STORE I
# 1      22173808.0         Issued  VAPE IT STORE II
# 2       2104436.0         Issued       VAPEPAD THE
# 3      17165957.0         Issued         VAPE FROG
# 4             NaN        Pending         VAPE FROG

# %% [markdown]
# ## Use Selenium to scrape ALL pages of results, save the results into `vape-results-all.csv`.

# %%
driver = webdriver.Chrome()
url = "https://jportal.mdcourts.gov/license/index_disclaimer.jsp"
driver.get(url)
checkbox = driver.find_element_by_xpath('//*[@id="checkbox"]')
checkbox.click()
button = driver.find_element_by_xpath('/html/body/table/tbody/tr[7]/td/form/div/input[2]')
button.click()
link = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[6]/td[2]/a[2]')
link.click()

# %%
dropdown = driver.find_element_by_xpath('//*[@id="slcJurisdiction"]')
select = Select(dropdown)
select.select_by_visible_text("Statewide")
tradeName = driver.find_element_by_xpath('//*[@id="txtTradeName"]')
tradeName.send_keys("vap%")
searchButton = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/form/table/tbody/tr[14]/td/input[1]')
searchButton.click()

# %%
def scrape_this_page():
    doc = BeautifulSoup(driver.page_source, "html.parser")
    business_headers = doc.find_all('tr',class_='searchfieldtitle')
    this_list = []
    
    for header in business_headers:
        company = {}
        rows = header.find_next_siblings('tr')
        company['trade_name'] = header.find_all('td')[1].text.strip()
        company['company_name'] = rows[0].find_all('td')[1].text.strip()
        company['city_name'] = rows[2].find_all('td')[1].text.strip()
        company['address'] = rows[1].find_all('td')[1].text.strip()
        company['county'] = rows[3].find_all('td')[1].text.strip()
        company_url = header.find_all('td')[2].find('a', href=True)
        
        if company_url:
            company['detail_link'] = 'https://jportal.mdcourts.gov/license/'+company_url['href']
        else:
            company['detail_link'] = ''
            
        license_number = rows[1].find_all('td')[2].find('span')
        
        if license_number: 
            company['license_status'] = rows[0].find_all('td')[2].find('span').next_sibling.strip()
            company['license_number'] = license_number.next_sibling.strip()
            company['issue_date'] = rows[2].find_all('td')[2].find('span').next_sibling.strip()
        else:
            company['license_status'] = rows[0].find_all('td')[2].find('span').next_sibling.strip()
            company['license_number'] = ""
            company['issue_date'] = ""
            
        this_list.append(company)
        
    return this_list

# %%
list_companies = []

while True:
    try:
        this_list = scrape_this_page()
        list_companies += this_list
        nextButton = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[2]/tbody/tr/td[3]/a/nobr')
        nextButton.click()
    except:
        break

# %%
df = pd.DataFrame(list_companies)
df.to_csv('vape_results_all.csv',index=False)

# %%
df = pd.read_csv('vape_results_all.csv', converters={'license_number': str})
df
# Out:
#                              address                 city_name  \
# 0       1724 N SALISBURY BLVD UNIT 2       SALISBURY, MD 21801
# 1              1015 S SALISBURY BLVD       SALISBURY, MD 21801
# 2            2299 JOHNS HOPKINS ROAD       GAMBRILLS, MD 21054
# 3                    110 S. PINEY RD         CHESTER, MD 21619
# 4                346 RITCHIE HIGHWAY    SEVERNA PARK, MD 21146
# 5            185 MITCHELLS CHANCE RD       EDGEWATER, MD 21037
# 6              7104 MINSTREL UNIT #7        COLUMBIA, MD 21045
# 7         330 ONE FORTY VILLAGE ROAD     WESTMINSTER, MD 21157
# 8             29890 THREE NOTCH ROAD  CHARLOTTE HALL, MD 20622
# 9                 356 ROMANCOKE ROAD    STEVENSVILLE, MD 21666
# 10         110 S PINEY ROAD  STE 106         CHESTER, MD 21619
# 11            28943 THREE NOTCH ROAD  MECHANICSVILLE, MD 20659
# 0   https://jportal.mdcourts.gov/license/pbLicense...  4/27/2017
# 1   https://jportal.mdcourts.gov/license/pbLicense...  4/27/2017
# 2   https://jportal.mdcourts.gov/license/pbLicense...  4/05/2017
# 3   https://jportal.mdcourts.gov/license/pbLicense...  5/31/2017
# 4                                                 NaN        NaN
# 5   https://jportal.mdcourts.gov/license/pbLicense...  4/13/2017
# 6   https://jportal.mdcourts.gov/license/pbLicense...  5/19/2017
# 7   https://jportal.mdcourts.gov/license/pbLicense...  4/21/2017
# 8                                                 NaN        NaN
# 9   https://jportal.mdcourts.gov/license/pbLicense...  4/13/2017
# 10                                                NaN        NaN
# 11  https://jportal.mdcourts.gov/license/pbLicense...  5/17/2017
# 12                                                NaN        NaN
# 13                                                NaN        NaN
# 14                                                NaN        NaN
# 15                                                NaN        NaN
# 16                                                NaN        NaN
# 17                                                NaN        NaN
# 18  https://jportal.mdcourts.gov/license/pbLicense...  5/05/2017
# 19  https://jportal.mdcourts.gov/license/pbLicense...  4/18/2017
# 20  https://jportal.mdcourts.gov/license/pbLicense...  3/31/2017
# 21                                                NaN        NaN
# 22                                                NaN        NaN
# 23  https://jportal.mdcourts.gov/license/pbLicense...  5/03/2017
# 24  https://jportal.mdcourts.gov/license/pbLicense...  5/10/2017
# 25  https://jportal.mdcourts.gov/license/pbLicense...  4/14/2017
# 26  https://jportal.mdcourts.gov/license/pbLicense...  4/12/2017
# 27  https://jportal.mdcourts.gov/license/pbLicense...  4/12/2017
# 28  https://jportal.mdcourts.gov/license/pbLicense...  4/03/2017
# 29                                                NaN        NaN
# 30  https://jportal.mdcourts.gov/license/pbLicense...  3/27/2017
# 31                                                NaN        NaN
#
#    license_number license_status        trade_name
# 0        22173807         Issued   VAPE IT STORE I
# 1        22173808         Issued  VAPE IT STORE II
# 2        02104436         Issued       VAPEPAD THE
# 3        17165957         Issued         VAPE FROG
# 4                        Pending         VAPE FROG
# 5        02102408         Issued   VAPE LOFT (THE)
# 6        13141786         Issued      VAPE N CIGAR
# 7        06126253         Issued         VAPE DOJO
# 8                        Pending        VAPE HAVEN
# 9        17166688         Issued         VAPE BIRD
# 10                       Pending         VAPE FROG
# 11       18167503         Issued     VAPORS LOUNGE
# 12                       Pending     VAPORS LOUNGE
# 13                       Pending         VAPIST MD
# 14                       Pending     VAPIST MD LLC
# 15                       Pending        VAPERTETMD
# 16                       Pending        VAPERTEKMD
# 17                       Pending          VAPORIOT
# 18       23178140         Issued         VAPE PLUS
# 19       15155429         Issued      VAPE  SOCIAL
# 20       08131285         Issued       VAPE JUNGLE
# 21                       Pending         VAPE TIME
# 22                       Pending    VAPEBAR EXPESS
# 23       16165362         Issued          VAPOR 99
# 24       20170900         Issued       VAPOR ALLEY
# 25       10135432         Issued    VAPOR EMPORIUM
# 26       03121958         Issued       VAPOR VILLA
# 27       03121959         Issued       VAPOR VILLA
# 28       12140135         Issued         VAPE DOJO
# 29                       Pending         VAPE DOJO
# 30       13144108         Issued         VAPE DOJO
# 31                       Pending   VAPEZ YARDHOUSE
