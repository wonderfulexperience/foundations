# %%
import pandas as pd

# %%
df = pd.read_csv('Full_Release.csv')

# %%
df
# Out:
#     District  Unnamed: 1            Facility Name    Facility City  \
# 0        NaN           1          CALHOUN CO JAIL         ANNISTON
# 1        NaN           1        JEFFERSON CO JAIL       BIRMINGHAM
# 2        NaN           1           MORGAN CO JAIL          DECATUR
# 3        NaN           1       TUSCALOOSA CO JAIL       TUSCALOOSA
# 4        NaN           1      CULLMAN CO DETN CTR          CULLMAN
# 5        NaN           1  HOOVER POLICE DEPARTMEN           HOOVER
# 6        NaN           1  CLAY COUNTY DETENTION C             CLAY
# 7        NaN           2          LEE CO DETN CTR          OPELIKA
# 8        NaN           2       MONTGOMERY CO JAIL       MONTGOMERY
# 9        NaN           2           ELMORE CO JAIL         WETUMPKA
# 10       NaN           2  JUST CARE - COLUMBIA RE         COLUMBIA
# 11       NaN           2     MONTGOMERY CITY JAIL       MONTGOMERY
# 12       NaN           2   Local Medical Facility              NaN
# ...

# %%
df['Population'] = df['Unnamed: 37']

# %%
df['District'] = df['Unnamed: 1']

# %%
df[['Facility Name', 'Population']].to_csv('export.csv', index=False)
