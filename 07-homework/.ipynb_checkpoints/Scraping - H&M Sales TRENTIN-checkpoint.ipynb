# %% [markdown]
# # Scraping: H&M Sales
#
# **It's officially hot outside**, which means we need some summertime clothes. We live in New York City, though, so all our money goes to rent: we need to shop *as cheaply as possible*. So let's shop [sales at H&M](http://www.hm.com/us/products/sale)!
#
# **Answer the questions below using either Men's or Women's sale items at H&M.**
#
# ## Preparation: knowing your tags
#
# ### What is the tag name and class name for a product?

# %%
#tag name is div, class name is product-list-item

# %% [markdown]
# ### What is the tag name and class name for the old price? The new price?

# %%
#tag name is span, class name is "price" and "old-price"

# %% [markdown]
# ### What is the tag name and class name for the link to the product page?

# %%
#tag name is "a", class name is "product-url js-product-tracking"

# %% [markdown]
# ## Setup: Import what you'll need to scrape the page
#
# Use `requests`, not `urllib`.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# ## Try to scrape the page: how many product names can you find?
#
# "Try" to do it, because it *will not work.* Once you've learned that it won't work, spend a few minutes **looking at the page code** to see if you can figure out why.
#
# Eventually, ask for help by writing on the board.

# %%
response = requests.get("http://api.hm.com/v2/us/en/products/display?categories=sale&concealCategories=true&pageSize=60&page=1&deviceType=DESKTOP")
data = response.json()
data
# Out:
# {'content': [],
#  'displayArticles': [{'activityArticleNumber': '041829',
#    'additionalImages': [],
#    'articleCode': '60133-E',
#    'assortmentState': 'CURRENT',
#    'availableSizeInfo': [{'sizeName': 'XS', 'stockSize': '003'},
#     {'sizeName': 'S', 'stockSize': '004'},
#     {'sizeName': 'M', 'stockSize': '005'},
#     {'sizeName': 'L', 'stockSize': '006'}],
#    'availableSwatches': [{'articleCode': '60133-E',
#      'castorArticleId': '0458058005',
#      'colour': '000000',
#      'fabricImageResource': '/fabric/2016/3D493D1F-213C-4CC1-96E4-E6D7D2E3FD75.jpg',
#      'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2016/3D493D1F-213C-4CC1-96E4-E6D7D2E3FD75.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#    'castorArticleNumber': '005',
#    'castorProductNumber': '0458058',
#    'colourDescription': 'Black',
#    'departments': [{'code': 'LADIES',
#      'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#      'paths': ['LADIES/LADIES_TOPS/LADIES_TOPS_SHORT_SLEEVED',
#       'LADIES/LADIES_BASICS/LADIES_BASICS_TOPS/LADIES_BASICS_TOPS_SHORTSLEEVE']}],
#    'name': 'Jersey Top',
#    'priceInfo': {'currencyIso': 'USD',
#     'currencySymbol': '$',
#     'formattedOldPrice': '$12.99',
#     'formattedPrice': '$5',
#     'onSale': True,
#     'prefixCurrencySymbol': '$',
#     'price': 5.0,
#     'suffixCurrencySymbol': ''},
#    'primaryImage': {'type': 'STILL_LIFE_FRONT',
#     'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2016/E00 0458058 005 25 1075.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[1]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#    'productNumber': '60133',
#    'stockState': 'IN_STOCK',
#    'textualMarkers': [],
#    'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs2MDEzMy0xX2VuX1VTOzYwMTMzLUVfZW5fVVM7O05PTkU6Tk9ORTs0Ow'},
#    'webUrl': 'http://www.hm.com/us/product/60133?article=60133-E'},
#   {'activityArticleNumber': '525038',
#    'additionalImages': [],
#    'articleCode': '60133-F',
#    'assortmentState': 'CURRENT',
#    'availableSizeInfo': [{'sizeName': 'XS', 'stockSize': '003'},
#     {'sizeName': 'S', 'stockSize': '004'},
#     {'sizeName': 'M', 'stockSize': '005'},
#     {'sizeName': 'L', 'stockSize': '006'}],
#    'availableSwatches': [{'articleCode': '60133-F',
#      'castorArticleId': '0458058008',
#      'colour': 'f69eb7',
#      'fabricImageResource': '/fabric/2016/BE6AFADA-1871-417D-9821-7103F37463B7.jpg',
#      'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2016/BE6AFADA-1871-417D-9821-7103F37463B7.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#    'castorArticleNumber': '008',
#    'castorProductNumber': '0458058',
#    'colourDescription': 'Light pink melange',
#    'departments': [{'code': 'LADIES',
#      'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#      'paths': ['LADIES/LADIES_TOPS/LADIES_TOPS_SHORT_SLEEVED',
#       'LADIES/LADIES_BASICS/LADIES_BASICS_TOPS/LADIES_BASICS_TOPS_SHORTSLEEVE']}],
#    'name': 'Jersey Top',
#    'priceInfo': {'currencyIso': 'USD',
#     'currencySymbol': '$',
#     'formattedOldPrice': '$12.99',
#     'formattedPrice': '$5',
#     'onSale': True,
#     'prefixCurrencySymbol': '$',
#     'price': 5.0,
#     'suffixCurrencySymbol': ''},
#    'primaryImage': {'type': 'STILL_LIFE_FRONT',
#     'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2016/E00 0458058 008 25 1076.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[1]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#    'productNumber': '60133',
#    'stockState': 'IN_STOCK',
#    'textualMarkers': [],
#    'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs2MDEzMy0yX2VuX1VTOzYwMTMzLUZfZW5fVVM7O05PTkU6Tk9ORTs0Ow'},
#    'webUrl': 'http://www.hm.com/us/product/60133?article=60133-F'},
#   {'activityArticleNumber': '352079',
#    'additionalImages': [],
#    'articleCode': '58550-J',
#    'assortmentState': 'CURRENT',
#    'availableSizeInfo': [{'sizeName': '4', 'stockSize': '034'},
#     {'sizeName': '6', 'stockSize': '036'},
#     {'sizeName': '8', 'stockSize': '038'},
#     {'sizeName': '10', 'stockSize': '040'},
#     {'sizeName': '12', 'stockSize': '042'},
#     {'sizeName': '18', 'stockSize': '048'},
#     {'sizeName': '20', 'stockSize': '050'}],
#    'availableSwatches': [{'articleCode': '58550-F',
#      'castorArticleId': '0434429017',
#      'colour': '161e80',
#      'fabricImageResource': '/fabric/2016/A55E1A83-B8C6-4A00-B1A8-AD3DE8114DCB.jpg',
#      'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2016/A55E1A83-B8C6-4A00-B1A8-AD3DE8114DCB.jpg]&call=url[file:/mobile/v1/fabric/sprite]'},
#     {'articleCode': '58550-J',
#      'castorArticleId': '0434429016',
#      'colour': '9ba0e7',
#      'fabricImageResource': '/fabric/2017/A2598404-D177-48D5-BEC6-A1C923E9B93F.jpg',
#      'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/A2598404-D177-48D5-BEC6-A1C923E9B93F.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#    'castorArticleNumber': '016',
#    'castorProductNumber': '0434429',
#    'colourDescription': 'Light denim blue',
#    'departments': [{'code': 'LADIES',
#      'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#      'paths': ['LADIES/LADIES_EVERYDAY_FASHION/LADIES_EVERYDAY_FASHION_TROUSERS_JEANS',
#       'LADIES/LADIES_TROUSERS/LADIES_TROUSERS_SLIM']}],
#    'name': 'Super-slim-fit Pants',
#    'priceInfo': {'currencyIso': 'USD',
#     'currencySymbol': '$',
#     'formattedOldPrice': '$19.99',
#     'formattedPrice': '$9.99',
#     'onSale': True,
#     'prefixCurrencySymbol': '$',
#     'price': 9.99,
#     'suffixCurrencySymbol': ''},
#    'primaryImage': {'type': 'STILL_LIFE_FRONT',
#     'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2017/E00 0434429 016 14 1800.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[2]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#    'productNumber': '58550',
#    'stockState': 'IN_STOCK',
#    'textualMarkers': [],
#    'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs1ODU1MC0yX2VuX1VTOzU4NTUwLUpfZW5fVVM7O05PTkU6Tk9ORTs0Ow'},
#    'webUrl': 'http://www.hm.com/us/product/58550?article=58550-J'},
#   {'activityArticleNumber': '739672',
#    'additionalImages': [],
#    'articleCode': '58550-I',
#    'assortmentState': 'CURRENT',
#    'availableSizeInfo': [{'sizeName': '2', 'stockSize': '032'},
#     {'sizeName': '4', 'stockSize': '034'},
#     {'sizeName': '6', 'stockSize': '036'},
#     {'sizeName': '8', 'stockSize': '038'},
#     {'sizeName': '10', 'stockSize': '040'},
#     {'sizeName': '12', 'stockSize': '042'},
#     {'sizeName': '14', 'stockSize': '044'},
#     {'sizeName': '16', 'stockSize': '046'},
#     {'sizeName': '18', 'stockSize': '048'},
#     {'sizeName': '20', 'stockSize': '050'}],
#    'availableSwatches': [{'articleCode': '58550-I',
#      'castorArticleId': '0434429024',
#      'colour': 'ffffff',
#      'fabricImageResource': '/fabric/2016/BF18D56D-8AC4-47F2-8327-8E3C3A6870E7.jpg',
#      'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2016/BF18D56D-8AC4-47F2-8327-8E3C3A6870E7.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#    'castorArticleNumber': '024',
#    'castorProductNumber': '0434429',
#    'colourDescription': 'White',
#    'departments': [{'code': 'LADIES',
#      'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#      'paths': ['LADIES/LADIES_EVERYDAY_FASHION/LADIES_EVERYDAY_FASHION_TROUSERS_JEANS',
#       'LADIES/LADIES_TROUSERS/LADIES_TROUSERS_SLIM']}],
#    'name': 'Super-slim-fit Pants',
#    'priceInfo': {'currencyIso': 'USD',
#     'currencySymbol': '$',
#     'formattedOldPrice': '$19.99',
#     'formattedPrice': '$9.99',
#     'onSale': True,
#     'prefixCurrencySymbol': '$',
#     'price': 9.99,
#     'suffixCurrencySymbol': ''},
#    'primaryImage': {'type': 'STILL_LIFE_FRONT',
#     'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2016/E00 0434429 024 32 1253.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[4]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#    'productNumber': '58550',
#    'stockState': 'IN_STOCK',
#    'textualMarkers': [],
#    'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs1ODU1MC00X2VuX1VTOzU4NTUwLUlfZW5fVVM7O05PTkU6Tk9ORTs0Ow'},
#    'webUrl': 'http://www.hm.com/us/product/58550?article=58550-I'},
#   {'activityArticleNumber': '566804',
#    'additionalImages': [],
#    'articleCode': '63201-E',
#    'assortmentState': 'CURRENT',
#    'availableSizeInfo': [{'sizeName': '2', 'stockSize': '032'},
#     {'sizeName': '4', 'stockSize': '034'},
#     {'sizeName': '6', 'stockSize': '036'},
#     {'sizeName': '8', 'stockSize': '038'},
#     {'sizeName': '10', 'stockSize': '040'},
#     {'sizeName': '12', 'stockSize': '042'},
#     {'sizeName': '14', 'stockSize': '044'}],
#    'availableSwatches': [{'articleCode': '63201-E',
#      'castorArticleId': '0479205006',
#      'colour': 'c41503',
#      'fabricImageResource': '/fabric/2017/0799C72E-6D4B-494F-8673-3FB3BD1CFF07.jpg',
#      'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/0799C72E-6D4B-494F-8673-3FB3BD1CFF07.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#    'castorArticleNumber': '006',
#    'castorProductNumber': '0479205',
#    'colourDescription': 'Red',
#    'departments': [{'code': 'LADIES',
#      'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#      'paths': ['LADIES/LADIES_SHIRTS_BLOUSES/LADIES_SHIRTS_BLOUSES_BLOUSES',
#       'LADIES/LADIES_EVERYDAY_FASHION/LADIES_EVERYDAY_FASHION_SHIRTS_BLOUSES/LADIES_EVERYDAY_FASHION_SHIRTS_BLOUSES_BLOUSES']}],
#    'name': 'V-neck Blouse',
#    'priceInfo': {'currencyIso': 'USD',
#     'currencySymbol': '$',
#     'formattedOldPrice': '$17.99',
#     'formattedPrice': '$9.99',
#     'onSale': True,
#     'prefixCurrencySymbol': '$',
#     'price': 9.99,
#     'suffixCurrencySymbol': ''},
#    'primaryImage': {'type': 'STILL_LIFE_FRONT',
#     'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2017/E00 0479205 006 32 2439.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[1]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#    'productNumber': '63201',
#    'stockState': 'IN_STOCK',
#    'textualMarkers': [],
#    'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs2MzIwMS00X2VuX1VTOzYzMjAxLUVfZW5fVVM7O05PTkU6Tk9ORTs0Ow'},
#    'webUrl': 'http://www.hm.com/us/product/63201?article=63201-E'},
#   {'activityArticleNumber': '657829',
#    'additionalImages': [],
#    'articleCode': '68934-C',
#    'assortmentState': 'CURRENT',
#    'availableSizeInfo': [{'sizeName': 'M', 'stockSize': '005'},
#     {'sizeName': 'L', 'stockSize': '006'},
#     {'sizeName': 'XL', 'stockSize': '007'}],
#    'availableSwatches': [{'articleCode': '68934-C',
#      'castorArticleId': '0500557001',
#      'colour': 'ffffff',
#      'fabricImageResource': '/fabric/2017/B34B3EA1-8D02-4EC4-A1A7-A902E7D215C3.jpg',
#      'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/B34B3EA1-8D02-4EC4-A1A7-A902E7D215C3.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#    'castorArticleNumber': '001',
#    'castorProductNumber': '0500557',
#    'colourDescription': 'White',
#    'departments': [{'code': 'LADIES',
#      'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#      'paths': ['LADIES/LADIES_TOPS/LADIES_TOPS_SHORT_SLEEVED',
#       'LADIES/LADIES_BASICS/LADIES_BASICS_TOPS/LADIES_BASICS_TOPS_SHORTSLEEVE']}],
#    'name': 'Jersey Top',
#    'priceInfo': {'currencyIso': 'USD',
#     'currencySymbol': '$',
#     'formattedOldPrice': '$12.99',
#     'formattedPrice': '$5.99',
#     'onSale': True,
#     'prefixCurrencySymbol': '$',
#     'price': 5.99,
#     'suffixCurrencySymbol': ''},
#    'primaryImage': {'type': 'STILL_LIFE_FRONT',
#     'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2017/E00 0500557 001 49 3191.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[1]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#    'productNumber': '68934',
#    'stockState': 'IN_STOCK',
#    'textualMarkers': [],
#    'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs2ODkzNC0xX2VuX1VTOzY4OTM0LUNfZW5fVVM7O05PTkU6Tk9ORTs0Ow'},
#    'webUrl': 'http://www.hm.com/us/product/68934?article=68934-C'},
#   {'activityArticleNumber': '256463',
#    'additionalImages': [],
#    'articleCode': '58550-H',
#    'assortmentState': 'CURRENT',
#    'availableSizeInfo': [{'sizeName': '2', 'stockSize': '032'},
#     {'sizeName': '4', 'stockSize': '034'},
#     {'sizeName': '6', 'stockSize': '036'},
#     {'sizeName': '8', 'stockSize': '038'},
#     {'sizeName': '10', 'stockSize': '040'},
#     {'sizeName': '12', 'stockSize': '042'},
#     {'sizeName': '16', 'stockSize': '046'},
#     {'sizeName': '18', 'stockSize': '048'},
#     {'sizeName': '20', 'stockSize': '050'}],
#    'availableSwatches': [{'articleCode': '58550-H',
#      'castorArticleId': '0434429019',
#      'colour': 'f24e32',
#      'fabricImageResource': '/fabric/2016/B7E71B41-41EC-45C7-927A-7A431F918137.jpg',
#      'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2016/B7E71B41-41EC-45C7-927A-7A431F918137.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#    'castorArticleNumber': '019',
#    'castorProductNumber': '0434429',
#    'colourDescription': 'Powder',
#    'departments': [{'code': 'LADIES',
#      'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#      'paths': ['LADIES/LADIES_EVERYDAY_FASHION/LADIES_EVERYDAY_FASHION_TROUSERS_JEANS',
#       'LADIES/LADIES_TROUSERS/LADIES_TROUSERS_SLIM']}],
#    'name': 'Super-slim-fit Pants',
#    'priceInfo': {'currencyIso': 'USD',
#     'currencySymbol': '$',
#     'formattedOldPrice': '$19.99',
#     'formattedPrice': '$9.99',
#     'onSale': True,
#     'prefixCurrencySymbol': '$',
#     'price': 9.99,
#     'suffixCurrencySymbol': ''},
#    'primaryImage': {'type': 'STILL_LIFE_FRONT',
#     'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2016/E00 0434429 019 65 1008.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[1]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#    'productNumber': '58550',
#    'stockState': 'IN_STOCK',
#    'textualMarkers': [],
#    'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs1ODU1MC01X2VuX1VTOzU4NTUwLUhfZW5fVVM7O05PTkU6Tk9ORTs0Ow'},
#    'webUrl': 'http://www.hm.com/us/product/58550?article=58550-H'},
#   {'activityArticleNumber': '573246',
#    'additionalImages': [],
#    'articleCode': '66751-C',
#    'assortmentState': 'CURRENT',
#    'availableSizeInfo': [{'sizeName': 'XS', 'stockSize': '003'},
#     {'sizeName': 'S', 'stockSize': '004'}],
#    'availableSwatches': [{'articleCode': '66751-C',
#      'castorArticleId': '0459230008',
#      'colour': '3c3837',
#      'fabricImageResource': '/fabric/2017/093D757B-AF6B-4A60-947A-03AFC6A18D1A.jpg',
#      'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/093D757B-AF6B-4A60-947A-03AFC6A18D1A.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#    'castorArticleNumber': '008',
#    'castorProductNumber': '0459230',
#    'colourDescription': 'Dark gray/Mickey Mouse',
#    'departments': [{'code': 'LADIES',
#      'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#      'paths': ['LADIES/LADIES_NIGHTWEAR/LADIES_NIGHTWEAR_PYJAMAS']}],
#    'name': 'Pajama Tank Top and Shorts',
#    'priceInfo': {'currencyIso': 'USD',
#     'currencySymbol': '$',
#     'formattedOldPrice': '$14.99',
#     'formattedPrice': '$7.99',
#     'onSale': True,
#     'prefixCurrencySymbol': '$',
#     'price': 7.99,
#     'suffixCurrencySymbol': ''},
#    'primaryImage': {'type': 'STILL_LIFE_FRONT',
#     'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2017/E00 0459230 008 00 2299.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[0]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#    'productNumber': '66751',
#    'stockState': 'IN_STOCK',
#    'textualMarkers': [],
#    'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs2Njc1MS0zLTAtMTFfZW5fVVM7NjY3NTEtQ19lbl9VUzs7Tk9ORTpOT05FOzQ7'},
#    'webUrl': 'http://www.hm.com/us/product/66751?article=66751-C'},
#   {'activityArticleNumber': '774075',
#    'additionalImages': [],
#    'articleCode': '24792-N',
#    'assortmentState': 'CURRENT',
#    'availableSizeInfo': [{'sizeName': 'XS', 'stockSize': '003'},
#     {'sizeName': 'S', 'stockSize': '004'},
#     {'sizeName': 'M', 'stockSize': '005'},
#     {'sizeName': 'L', 'stockSize': '006'},
#     {'sizeName': 'XL', 'stockSize': '007'}],
#    'availableSwatches': [{'articleCode': '24792-N',
#      'castorArticleId': '0129393047',
#      'colour': 'd6ba9a',
#      'fabricImageResource': '/fabric/2017/7163FDAE-A416-470E-961C-767AA0C7FA55.jpg',
#      'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/7163FDAE-A416-470E-961C-767AA0C7FA55.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#    'castorArticleNumber': '047',
#    'castorProductNumber': '0129393',
#    'colourDescription': 'Beige melange',
#    'departments': [{'code': 'LADIES',
#      'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#      'paths': ['LADIES/LADIES_CARDIGANS_JUMPERS/LADIES_CARDIGANS_JUMPERS_CARDIGANS',
#       'LADIES/LADIES_BASICS/LADIES_BASICS_CARDIGANSJUMPERS']}],
#    'name': 'Fine-knit Cardigan',
#    'priceInfo': {'currencyIso': 'USD',
#     'currencySymbol': '$',
#     'formattedOldPrice': '$17.99',
#     'formattedPrice': '$9.99',
#     'onSale': True,
#     'prefixCurrencySymbol': '$',
#     'price': 9.99,
#     'suffixCurrencySymbol': ''},
#    'primaryImage': {'type': 'STILL_LIFE_FRONT',
#     'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2017/E00 0129393 047 65 1883.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[1]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#    'productNumber': '24792',
#    'stockState': 'IN_STOCK',
#    'textualMarkers': [],
#    'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTsyNDc5Mi00X2VuX1VTOzI0NzkyLU5fZW5fVVM7O05PTkU6Tk9ORTs0Ow'},
#    'webUrl': 'http://www.hm.com/us/product/24792?article=24792-N'},
#   {'activityArticleNumber': '547012',
#    'additionalImages': [],
#    'articleCode': '52725-A',
#    'assortmentState': 'CURRENT',
#    'availableSizeInfo': [{'sizeName': '4', 'stockSize': '034'},
#     {'sizeName': '6', 'stockSize': '036'},
#     {'sizeName': '8', 'stockSize': '038'},
#     {'sizeName': '10', 'stockSize': '040'},
#     {'sizeName': '12', 'stockSize': '042'}],
#    'availableSwatches': [{'articleCode': '52725-A',
#      'castorArticleId': '0417076001',
#      'colour': '161e80',
#      'fabricImageResource': '/fabric/2016/B16E3EDC-8F89-4CA6-B7D2-F84C17BF05C1.jpg',
#      'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2016/B16E3EDC-8F89-4CA6-B7D2-F84C17BF05C1.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#    'castorArticleNumber': '001',
#    'castorProductNumber': '0417076',
#    'colourDescription': 'Denim blue',
#    'departments': [{'code': 'LADIES',
#      'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#      'paths': ['LADIES/LADIES_SHIRTS_BLOUSES/LADIES_SHIRTS_BLOUSES_SHIRTS',
#       'LADIES/LADIES_SELECTED/LADIES_SELECTED_CONSCIOUS-SUSTAINABLE-STYLE']}],
#    'name': 'Lyocell Utility Shirt',
#    'priceInfo': {'currencyIso': 'USD',
#     'currencySymbol': '$',
#     'formattedOldPrice': '$34.99',
#     'formattedPrice': '$12.99',
#     'onSale': True,
#     'prefixCurrencySymbol': '$',
#     'price': 12.99,
#     'suffixCurrencySymbol': ''},
#    'primaryImage': {'type': 'STILL_LIFE_FRONT',
#     'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2016/D00 0417076 001 68 1950.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[3]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#    'productMarker': {'markerDescription': '',
#     'markerText': 'CONSCIOUS',
#     'markerType': 'CONSCIOUS'},
#    'productNumber': '52725',
#    'stockState': 'IN_STOCK',
#    'textualMarkers': [],
#    'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs1MjcyNS0xX2VuX1VTOzUyNzI1LUFfZW5fVVM7O05PTkU6Tk9ORTs0Ow'},
#    'webUrl': 'http://www.hm.com/us/product/52725?article=52725-A'},
#   {'activityArticleNumber': '328444',
#    'additionalImages': [],
#    'articleCode': '39061-A',
#    'assortmentState': 'CURRENT',
#    'availableSizeInfo': [{'sizeName': '4', 'stockSize': '034'},
#     {'sizeName': '6', 'stockSize': '036'},
#     {'sizeName': '8', 'stockSize': '038'},
#     {'sizeName': '10', 'stockSize': '040'},
#     {'sizeName': '12', 'stockSize': '042'},
#     {'sizeName': '14', 'stockSize': '044'},
#     {'sizeName': '16', 'stockSize': '046'}],
#    'availableSwatches': [{'articleCode': '39061-A',
#      'castorArticleId': '0356198001',
#      'colour': '000000',
#      'fabricImageResource': '/fabric/2015/A7B9BB42-5F39-44BE-9C4D-BF369DC20DA8.jpg',
#      'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2015/A7B9BB42-5F39-44BE-9C4D-BF369DC20DA8.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#    'castorArticleNumber': '001',
#    'castorProductNumber': '0356198',
#    'colourDescription': 'Black',
#    'departments': [{'code': 'LADIES',
#      'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#      'paths': ['LADIES/LADIES_EVERYDAY_FASHION/LADIES_EVERYDAY_FASHION_TROUSERS_JEANS',
#       'LADIES/LADIES_TROUSERS/LADIES_TROUSERS_LEGGINGS']}],
#    'name': 'Slim-fit Treggings',
#    'priceInfo': {'currencyIso': 'USD',
#     'currencySymbol': '$',
#     'formattedOldPrice': '$19.99',
#     'formattedPrice': '$12.99',
#     'onSale': True,
#     'prefixCurrencySymbol': '$',
#     'price': 12.99,
#     'suffixCurrencySymbol': ''},
#    'primaryImage': {'type': 'STILL_LIFE_FRONT',
#     'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2015/C00 0356198 001 38 1350.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[4]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#    'productNumber': '39061',
#    'stockState': 'IN_STOCK',
#    'textualMarkers': [],
#    'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTszOTA2MS0xX2VuX1VTOzM5MDYxLUFfZW5fVVM7O05PTkU6Tk9ORTs0Ow'},
#    'webUrl': 'http://www.hm.com/us/product/39061?article=39061-A'},
#   {'activityArticleNumber': '655334',
#    'additionalImages': [],
#    'articleCode': '65450-C',
#    'assortmentState': 'CURRENT',
#    'availableSizeInfo': [{'sizeName': '2', 'stockSize': '032'},
#     {'sizeName': '4', 'stockSize': '034'},
#     {'sizeName': '6', 'stockSize': '036'},
#     {'sizeName': '8', 'stockSize': '038'},
#     {'sizeName': '10', 'stockSize': '040'},
#     {'sizeName': '12', 'stockSize': '042'}],
#    'availableSwatches': [{'articleCode': '65450-C',
#      'castorArticleId': '0484639002',
#      'colour': '9ba0e7',
#      'fabricImageResource': '/fabric/2017/E1D19961-337D-419C-9BCB-C97965BD77F5.jpg',
#      'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/E1D19961-337D-419C-9BCB-C97965BD77F5.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#    'castorArticleNumber': '002',
#    'castorProductNumber': '0484639',
#    'colourDescription': 'Light blue/dotted',
#    'departments': [{'code': 'LADIES',
#      'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#      'paths': ['LADIES/LADIES_SHIRTS_BLOUSES/LADIES_SHIRTS_BLOUSES_BLOUSES',
#       'LADIES/LADIES_EVERYDAY_FASHION/LADIES_EVERYDAY_FASHION_SHIRTS_BLOUSES/LADIES_EVERYDAY_FASHION_SHIRTS_BLOUSES_BLOUSES']}],
#    'name': 'Cotton Blouse',
#    'priceInfo': {'currencyIso': 'USD',
#     'currencySymbol': '$',
#     'formattedOldPrice': '$17.99',
#     'formattedPrice': '$9.99',
#     'onSale': True,
#     'prefixCurrencySymbol': '$',
#     'price': 9.99,
#     'suffixCurrencySymbol': ''},
#    'primaryImage': {'type': 'STILL_LIFE_FRONT',
#     'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2017/E00 0484639 002 55 2453.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[1]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#    'productNumber': '65450',
#    'stockState': 'IN_STOCK',
#    'textualMarkers': [],
#    'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs2NTQ1MC0xX2VuX1VTOzY1NDUwLUNfZW5fVVM7O05PTkU6Tk9ORTs0Ow'},
#    'webUrl': 'http://www.hm.com/us/product/65450?article=65450-C'},
#   {'activityArticleNumber': '443598',
#    'additionalImages': [],
#    'articleCode': '61242-B',
#    'assortmentState': 'CURRENT',
#    'availableSizeInfo': [{'sizeName': 'XS', 'stockSize': '003'},
#     {'sizeName': 'S', 'stockSize': '004'},
#     {'sizeName': 'M', 'stockSize': '005'},
#     {'sizeName': 'L', 'stockSize': '006'}],
#    'availableSwatches': [{'articleCode': '61242-B',
#      'castorArticleId': '0452885003',
#      'colour': 'b8aba7',
#      'fabricImageResource': '/fabric/2016/469FC78E-FC24-46ED-9D6E-9319B6C535DF.jpg',
#      'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2016/469FC78E-FC24-46ED-9D6E-9319B6C535DF.jpg]&call=url[file:/mobile/v1/fabric/sprite]'},
#     {'articleCode': '61242-I',
#      'castorArticleId': '0452885013',
#      'colour': '008e4d',
#      'fabricImageResource': '/fabric/2017/5D78D05E-9C65-406D-8431-CAF0D81F4BC1.jpg',
#      'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/5D78D05E-9C65-406D-8431-CAF0D81F4BC1.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#    'castorArticleNumber': '003',
#    'castorProductNumber': '0452885',
#    'colourDescription': 'Light gray/swallows',
#    'departments': [{'code': 'LADIES',
#      'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#      'paths': ['LADIES/LADIES_CARDIGANS_JUMPERS/LADIES_CARDIGANS_JUMPERS_HOODIES',
#       'LADIES/LADIES_DIVIDED/LADIES_DIVIDED_HOODIES']}],
#    'name': 'Printed Sweatshirt',
#    'priceInfo': {'currencyIso': 'USD',
#     'currencySymbol': '$',
#     'formattedOldPrice': '$9.99',
#     'formattedPrice': '$5.99',
#     'onSale': True,
#     'prefixCurrencySymbol': '$',
#     'price': 5.99,
#     'suffixCurrencySymbol': ''},
#    'primaryImage': {'type': 'STILL_LIFE_FRONT',
#     'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2016/E00 0452885 003 42 0842.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[1]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#    'productNumber': '61242',
#    'stockState': 'IN_STOCK',
#    'textualMarkers': [],
#    'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs2MTI0Mi0xX2VuX1VTOzYxMjQyLUJfZW5fVVM7O05PTkU6Tk9ORTs0Ow'},
#    'webUrl': 'http://www.hm.com/us/product/61242?article=61242-B'},
#   {'activityArticleNumber': '424060',
#    'additionalImages': [],
#    'articleCode': '39061-E',
#    'assortmentState': 'CURRENT',
#    'availableSizeInfo': [{'sizeName': '4', 'stockSize': '034'},
#     {'sizeName': '6', 'stockSize': '036'},
#     {'sizeName': '8', 'stockSize': '038'},
#     {'sizeName': '10', 'stockSize': '040'},
#     {'sizeName': '12', 'stockSize': '042'},
#     {'sizeName': '14', 'stockSize': '044'},
#     {'sizeName': '16', 'stockSize': '046'}],
#    'availableSwatches': [{'articleCode': '39061-E',
#      'castorArticleId': '0356198005',
#      'colour': '020f41',
#      'fabricImageResource': '/fabric/2015/076B998C-78CD-4EDB-A3C6-742266984657.jpg',
#      'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2015/076B998C-78CD-4EDB-A3C6-742266984657.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#    'castorArticleNumber': '005',
#    'castorProductNumber': '0356198',
#    'colourDescription': 'Dark blue',
#    'departments': [{'code': 'LADIES',
#      'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#      'paths': ['LADIES/LADIES_EVERYDAY_FASHION/LADIES_EVERYDAY_FASHION_TROUSERS_JEANS',
#       'LADIES/LADIES_TROUSERS/LADIES_TROUSERS_LEGGINGS']}],
#    'name': 'Slim-fit Treggings',
#    'priceInfo': {'currencyIso': 'USD',
#     'currencySymbol': '$',
#     'formattedOldPrice': '$19.99',
#     'formattedPrice': '$12.99',
#     'onSale': True,
#     'prefixCurrencySymbol': '$',
#     'price': 12.99,
#     'suffixCurrencySymbol': ''},
#    'primaryImage': {'type': 'STILL_LIFE_FRONT',
#     'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2015/C00 0356198 005 93 1951.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[3]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#    'productNumber': '39061',
#    'stockState': 'IN_STOCK',
#    'textualMarkers': [],
#    'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTszOTA2MS0yX2VuX1VTOzM5MDYxLUVfZW5fVVM7O05PTkU6Tk9ORTs0Ow'},
#    'webUrl': 'http://www.hm.com/us/product/39061?article=39061-E'},
#   {'activityArticleNumber': '750994',
#    'additionalImages': [],
#    'articleCode': '65743-D',
#    'assortmentState': 'CURRENT',
#    'availableSizeInfo': [{'sizeName': 'XS', 'stockSize': '003'},
#     {'sizeName': 'S', 'stockSize': '004'},
#     {'sizeName': 'M', 'stockSize': '005'},
#     {'sizeName': 'L', 'stockSize': '006'},
#     {'sizeName': 'XL', 'stockSize': '007'},
#     {'sizeName': 'XXL', 'stockSize': '008'}],
#    'availableSwatches': [{'articleCode': '65743-D',
#      'castorArticleId': '0451456001',
#      'colour': 'abc0ef',
#      'fabricImageResource': '/fabric/2017/7232AAAF-1C35-4CA5-B671-B87C82B71B04.jpg',
#      'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/7232AAAF-1C35-4CA5-B671-B87C82B71B04.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#    'castorArticleNumber': '001',
#    'castorProductNumber': '0451456',
#    'colourDescription': 'Denim blue',
#    'departments': [{'code': 'MEN',
#      'name': 'NAVIGATION.LABEL.DEPARTMENT.MEN',
#      'paths': ['MEN/MEN_HM_MAN/MEN_HM_MAN_SHIRTS',
#       'MEN/MEN_SHIRTS/MEN_SHIRTS_CASUAL']}],
#    'name': 'Short-sleeved Shirt Slim fit',
#    'priceInfo': {'currencyIso': 'USD',
#     'currencySymbol': '$',
#     'formattedOldPrice': '$17.99',
#     'formattedPrice': '$7.99',
#     'onSale': True,
#     'prefixCurrencySymbol': '$',
#     'price': 7.99,
#     'suffixCurrencySymbol': ''},
#    'primaryImage': {'type': 'STILL_LIFE_FRONT',
#     'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2017/E00 0451456 001 64 0056.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[1]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#    'productNumber': '65743',
#    'stockState': 'IN_STOCK',
#    'textualMarkers': [{'markerDescription': '',
#      'markerText': 'Online Exclusive',
#      'markerType': 'ONLINE_EXCLUSIVE'}],
#    'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs2NTc0My00X2VuX1VTOzY1NzQzLURfZW5fVVM7O05PTkU6Tk9ORTs0Ow'},
#    'webUrl': 'http://www.hm.com/us/product/65743?article=65743-D'},
#   {'activityArticleNumber': '744801',
#    'additionalImages': [],
#    'articleCode': '58550-D',
#    'assortmentState': 'CURRENT',
#    'availableSizeInfo': [{'sizeName': '2', 'stockSize': '032'},
#     {'sizeName': '4', 'stockSize': '034'},
#     {'sizeName': '6', 'stockSize': '036'},
#     {'sizeName': '8', 'stockSize': '038'},
#     {'sizeName': '10', 'stockSize': '040'},
#     {'sizeName': '12', 'stockSize': '042'},
#     {'sizeName': '14', 'stockSize': '044'},
#     {'sizeName': '16', 'stockSize': '046'},
#     {'sizeName': '18', 'stockSize': '048'},
#     {'sizeName': '20', 'stockSize': '050'}],
#    'availableSwatches': [{'articleCode': '58550-D',
#      'castorArticleId': '0434429007',
#      'colour': '807774',
#      'fabricImageResource': '/fabric/2016/BB43C92F-E514-4CF3-818B-61151BF75636.jpg',
#      'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2016/BB43C92F-E514-4CF3-818B-61151BF75636.jpg]&call=url[file:/mobile/v1/fabric/sprite]'},
#     {'articleCode': '58550-E',
#      'castorArticleId': '0434429013',
#      'colour': '3c3837',
#      'fabricImageResource': '/fabric/2016/5E1E9961-B85B-435C-B15B-E11D902E3184.jpg',
#      'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2016/5E1E9961-B85B-435C-B15B-E11D902E3184.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#    'castorArticleNumber': '007',
#    'castorProductNumber': '0434429',
#    'colourDescription': 'Gray denim',
#    'departments': [{'code': 'LADIES',
#      'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#      'paths': ['LADIES/LADIES_EVERYDAY_FASHION/LADIES_EVERYDAY_FASHION_TROUSERS_JEANS',
#       'LADIES/LADIES_TROUSERS/LADIES_TROUSERS_SLIM']}],
#    'name': 'Super-slim-fit Pants',
#    'priceInfo': {'currencyIso': 'USD',
#     'currencySymbol': '$',
#     'formattedOldPrice': '$19.99',
#     'formattedPrice': '$9.99',
#     'onSale': True,
#     'prefixCurrencySymbol': '$',
#     'price': 9.99,
#     'suffixCurrencySymbol': ''},
#    'primaryImage': {'type': 'STILL_LIFE_FRONT',
#     'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2016/E00 0434429 007 52 1225.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[4]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#    'productNumber': '58550',
#    'stockState': 'IN_STOCK',
#    'textualMarkers': [],
#    'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs1ODU1MC0zX2VuX1VTOzU4NTUwLURfZW5fVVM7O05PTkU6Tk9ORTs0Ow'},
#    'webUrl': 'http://www.hm.com/us/product/58550?article=58550-D'},
#   {'activityArticleNumber': '938544',
#    'additionalImages': [],
#    'articleCode': '47586-H',
#    'assortmentState': 'CURRENT',
#    'availableSizeInfo': [{'sizeName': 'XS', 'stockSize': '003'},
#     {'sizeName': 'S', 'stockSize': '004'},
#     {'sizeName': 'M', 'stockSize': '005'},
#     {'sizeName': 'L', 'stockSize': '006'},
#     {'sizeName': 'XL', 'stockSize': '007'}],
#    'availableSwatches': [{'articleCode': '47586-H',
#      'castorArticleId': '0371357019',
#      'colour': 'b8aba7',
#      'fabricImageResource': '/fabric/2017/82F5F363-2958-450B-9016-B1C7844E161F.jpg',
#      'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/82F5F363-2958-450B-9016-B1C7844E161F.jpg]&call=url[file:/mobile/v1/fabric/sprite]'},
#     {'articleCode': '47586-J',
#      'castorArticleId': '0371357020',
#      'colour': '5b3d25',
#      'fabricImageResource': '/fabric/2017/42BE525A-77C4-4855-9E6E-C1D6DCE2B334.jpg',
#      'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/42BE525A-77C4-4855-9E6E-C1D6DCE2B334.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#    'castorArticleNumber': '019',
#    'castorProductNumber': '0371357',
#    'colourDescription': 'Gray melange',
#    'departments': [{'code': 'MEN',
#      'name': 'NAVIGATION.LABEL.DEPARTMENT.MEN',
#      'paths': ['MEN/MEN_HM_MAN/MEN_HM_MAN_TSHIRTS_VESTS',
#       'MEN/MEN_TSHIRT/MEN_TSHIRT_SHORT_SLEEVED']}],
#    'name': 'Slub Jersey T-shirt',
#    'priceInfo': {'currencyIso': 'USD',
#     'currencySymbol': '$',
#     'formattedOldPrice': '$9.99',
#     'formattedPrice': '$5.99',
#     'onSale': True,
#     'prefixCurrencySymbol': '$',
#     'price': 5.99,
#     'suffixCurrencySymbol': ''},
#    'primaryImage': {'type': 'STILL_LIFE_FRONT',
#     'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2017/E00 0371357 019 28 2120.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[0]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#    'productNumber': '47586',
#    'stockState': 'IN_STOCK',
#    'textualMarkers': [],
#    'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs0NzU4Ni0xX2VuX1VTOzQ3NTg2LUhfZW5fVVM7O05PTkU6Tk9ORTs0Ow'},
#    'webUrl': 'http://www.hm.com/us/product/47586?article=47586-H'},
#   {'activityArticleNumber': '475160',
#    'additionalImages': [],
#    'articleCode': '68429-B',
#    'assortmentState': 'CURRENT',
#    'availableSizeInfo': [{'sizeName': 'XS', 'stockSize': '003'},
#     {'sizeName': 'S', 'stockSize': '004'},
#     {'sizeName': 'M', 'stockSize': '005'},
#     {'sizeName': 'L', 'stockSize': '006'},
#     {'sizeName': 'XL', 'stockSize': '007'}],
#    'availableSwatches': [{'articleCode': '68429-B',
#      'castorArticleId': '0485434003',
#      'colour': '807774',
#      'fabricImageResource': '/fabric/2017/E7D1AA86-63C2-484C-9E33-2BDB4B07E03F.jpg',
#      'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/E7D1AA86-63C2-484C-9E33-2BDB4B07E03F.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#    'castorArticleNumber': '003',
#    'castorProductNumber': '0485434',
#    'colourDescription': 'Gray melange',
#    'departments': [{'code': 'LADIES',
#      'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#      'paths': ['LADIES/LADIES_TOPS/LADIES_TOPS_SHORT_SLEEVED',
#       'LADIES/LADIES_EVERYDAY_FASHION/LADIES_EVERYDAY_FASHION_TOPS/LADIES_EVERYDAY_FASHION_TOPS_SHORTSLEEVE']}],
#    'name': 'Top with Lace Yoke',
#    'priceInfo': {'currencyIso': 'USD',
#     'currencySymbol': '$',
#     'formattedOldPrice': '$9.99',
#     'formattedPrice': '$5.99',
#     'onSale': True,
#     'prefixCurrencySymbol': '$',
#     'price': 5.99,
#     'suffixCurrencySymbol': ''},
#    'primaryImage': {'type': 'STILL_LIFE_FRONT',
#     'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2017/E00 0485434 003 62 3245.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[1]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#    'productNumber': '68429',
#    'stockState': 'IN_STOCK',
#    'textualMarkers': [],
#    'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs2ODQyOS0xX2VuX1VTOzY4NDI5LUJfZW5fVVM7O05PTkU6Tk9ORTs0Ow'},
#    'webUrl': 'http://www.hm.com/us/product/68429?article=68429-B'},
#   {'activityArticleNumber': '098794',
#    'additionalImages': [],
#    'articleCode': '13740-L',
#    'assortmentState': 'CURRENT',
#    'availableSizeInfo': [{'sizeName': 'XS', 'stockSize': '003'},
#     {'sizeName': 'S', 'stockSize': '004'},
#     {'sizeName': 'M', 'stockSize': '005'},
#     {'sizeName': 'L', 'stockSize': '006'}],
#    'availableSwatches': [{'articleCode': '13740-L',
#      'castorArticleId': '0189640037',
#      'colour': '807774',
#      'fabricImageResource': '/fabric/2015/E4A5679F-3A69-44D3-98AB-C712B724CFE6.jpg',
#      'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2015/E4A5679F-3A69-44D3-98AB-C712B724CFE6.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#    'castorArticleNumber': '037',
#    'castorProductNumber': '0189640',
#    'colourDescription': 'Gray melange',
#    'departments': [{'code': 'LADIES',
#      'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#      'paths': ['LADIES/LADIES_DIVIDED/LADIES_DIVIDED_BASICS/LADIES_DIVIDED_BASICS_JOGGERS_SWEATPANTS',
#       'LADIES/LADIES_BASICS/LADIES_BASICS_TROUSERS',
#       'LADIES/LADIES_DIVIDED/LADIES_DIVIDED_TROUSERS',
#       'LADIES/LADIES_TROUSERS/LADIES_TROUSERS_JOGGERS_SWEATPANTS']}],
#    'name': 'Sweatpants',
#    'priceInfo': {'currencyIso': 'USD',
#     'currencySymbol': '$',
#     'formattedOldPrice': '$19.99',
#     'formattedPrice': '$12.99',
#     'onSale': True,
#     'prefixCurrencySymbol': '$',
#     'price': 12.99,
#     'suffixCurrencySymbol': ''},
#    'primaryImage': {'type': 'STILL_LIFE_FRONT',
#     'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2015/B00 0189640 037 13 0375.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[2]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#    'productNumber': '13740',
#    'stockState': 'IN_STOCK',
#    'textualMarkers': [],
#    'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTsxMzc0MC0yX2VuX1VTOzEzNzQwLUxfZW5fVVM7O05PTkU6Tk9ORTs0Ow'},
#    'webUrl': 'http://www.hm.com/us/product/13740?article=13740-L'},
#   {'activityArticleNumber': '340593',
#    'additionalImages': [],
#    'articleCode': '66190-C',
#    'assortmentState': 'CURRENT',
#    'availableSizeInfo': [{'sizeName': '2', 'stockSize': '032'},
#     {'sizeName': '6', 'stockSize': '036'},
#     {'sizeName': '8', 'stockSize': '038'},
#     {'sizeName': '10', 'stockSize': '040'},
#     {'sizeName': '20', 'stockSize': '050'}],
#    'availableSwatches': [{'articleCode': '66190-C',
#      'castorArticleId': '0495206003',
#      'colour': '5b3d25',
#      'fabricImageResource': '/fabric/2017/6E38ADE6-2F1B-4DBF-9B69-58027548E31D.jpg',
#      'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/6E38ADE6-2F1B-4DBF-9B69-58027548E31D.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#    'castorArticleNumber': '003',
#    'castorProductNumber': '0495206',
#    'colourDescription': 'Khaki green',
#    'departments': [{'code': 'LADIES',
#      'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
#      'paths': ['LADIES/LADIES_JACKETS_COATS/LADIES_JACKETS_COATS_JACKETS',
#       'LADIES/LADIES_EVERYDAY_FASHION/LADIES_EVERYDAY_FASHION_JACKETS_COATS/LADIES_EVERYDAY_FASHION_JACKETS_COATS_JACKETS',
#       'LADIES/LADIES_SELECTED/LADIES_SELECTED_CONSCIOUS-SUSTAINABLE-STYLE']}],
#    'name': 'Lyocell Jacket',
#    'priceInfo': {'currencyIso': 'USD',
#     'currencySymbol': '$',
#     'formattedOldPrice': '$49.99',
#     'formattedPrice': '$19.99',
#     'onSale': True,
#     'prefixCurrencySymbol': '$',
#     'price': 19.99,
#     'suffixCurrencySymbol': ''},
#    'primaryImage': {'type': 'STILL_LIFE_FRONT',
#     'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2017/E00 0495206 003 66 2172.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[2]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#    'productMarker': {'markerDescription': '',
#     'markerText': 'CONSCIOUS',
#     'markerType': 'CONSCIOUS'},
#    'productNumber': '66190',
#    'stockState': 'IN_STOCK',
#    'textualMarkers': [],
#    'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs2NjE5MC01X2VuX1VTOzY2MTkwLUNfZW5fVVM7O05PTkU6Tk9ORTs0Ow'},
#    'webUrl': 'http://www.hm.com/us/product/66190?article=66190-C'},
#   {'activityArticleNumber': '526180',
#    'additionalImages': [],
#    'articleCode': '65743-A',
#    'assortmentState': 'CURRENT',
#    'availableSizeInfo': [{'sizeName': 'XS', 'stockSize': '003'},
#     {'sizeName': 'S', 'stockSize': '004'},
#     {'sizeName': 'M', 'stockSize': '005'},
#     {'sizeName': 'L', 'stockSize': '006'},
#     {'sizeName': 'XL', 'stockSize': '007'}],
#    'availableSwatches': [{'articleCode': '65743-A',
#      'castorArticleId': '0451456002',
#      'colour': '020f41',
#      'fabricImageResource': '/fabric/2017/5856055A-C8A9-4877-86C6-2EC86223B5AF.jpg',
#      'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2017/5856055A-C8A9-4877-86C6-2EC86223B5AF.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#    'castorArticleNumber': '002',
#    'castorProductNumber': '0451456',
#    'colourDescription': 'Dark denim blue',
#    'departments': [{'code': 'MEN',
#      'name': 'NAVIGATION.LABEL.DEPARTMENT.MEN',
#      'paths': ['MEN/MEN_HM_MAN/MEN_HM_MAN_SHIRTS',
#       'MEN/MEN_SHIRTS/MEN_SHIRTS_CASUAL']}],
#    'name': 'Short-sleeved Shirt Slim fit',
#    'priceInfo': {'currencyIso': 'USD',
#     'currencySymbol': '$',
#     'formattedOldPrice': '$17.99',
#     'formattedPrice': '$7.99',
#     'onSale': True,
#     'prefixCurrencySymbol': '$',
#     'price': 7.99,
#     'suffixCurrencySymbol': ''},
#    'primaryImage': {'type': 'STILL_LIFE_FRONT',
#     'url': '//lp.hm.com/hmprod?set=key[source],value[/model/2017/E00 0451456 002 98 2020.jpg]&set=key[rotate],value[]&set=key[width],value[]&set=key[height],value[]&set=key[x],value[]&set=key[y],value[]&set=key[type],value[STILL_LIFE_FRONT]&set=key[hmver],value[1]&set=key[quality],value[80]&set=key[size],value[346x405]&call=url[file:/mobile/v2/product]'},
#    'productNumber': '65743',
#    'stockState': 'IN_STOCK',
#    'textualMarkers': [{'markerDescription': '',
#      'markerText': 'Online Exclusive',
#      'markerType': 'ONLINE_EXCLUSIVE'}],
#    'trackingInfo': {'ticketId': 'Oy9wcm9kdWN0LWxpc3RpbmdzLXVzaW5nLWRwbi9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Qtd2l0aC1jb3VudC9wcm9kdWN0LWxpc3Q7Iztwcm9kdWN0X2tleTs2NTc0My01X2VuX1VTOzY1NzQzLUFfZW5fVVM7O05PTkU6Tk9ORTs0Ow'},
#    'webUrl': 'http://www.hm.com/us/product/65743?article=65743-A'},
#   {'activityArticleNumber': '627291',
#    'additionalImages': [],
#    'articleCode': '40949-E',
#    'assortmentState': 'CURRENT',
#    'availableSizeInfo': [{'sizeName': 'XS', 'stockSize': '003'},
#     {'sizeName': 'S', 'stockSize': '004'},
#     {'sizeName': 'M', 'stockSize': '005'},
#     {'sizeName': 'L', 'stockSize': '006'},
#     {'sizeName': 'XL', 'stockSize': '007'}],
#    'availableSwatches': [{'articleCode': '40949-E',
#      'castorArticleId': '0249165032',
#      'colour': '020f41',
#      'fabricImageResource': '/fabric/2016/205D18ED-9722-47C0-BEF6-26E2381D2018.jpg',
#      'fabricUrl': '//lp.hm.com/hmprod?set=source[/fabric/2016/205D18ED-9722-47C0-BEF6-26E2381D2018.jpg]&call=url[file:/mobile/v1/fabric/sprite]'}],
#    'castorArticleNumber': '032',
#    'castorProductNumber': '0249165',
#    'colourDescription': 'Dark blue/hearts',
#    'departments': [{'code': 'LADIES',
#      'name': 'NAVIGATION.LABEL.DEPARTMENT.LADIES',
# ...
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '7-8Y@15@1',
#       'name': '7-8Y',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '8-9Y@16@1',
#       'name': '8-9Y',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '9-10Y@17@1',
#       'name': '9-10Y',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '10-11Y@18@1',
#       'name': '10-11Y',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '11-12Y@19@1',
#       'name': '11-12Y',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '12-13Y@20@1',
#       'name': '12-13Y',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '13-14Y@21@1',
#       'name': '13-14Y',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '14Y+@22@1',
#       'name': '14Y+',
#       'selectable': True,
#       'selected': False}]},
#    {'id': 'Size Filter Category_Men clothes',
#     'label': "Men's Clothing",
#     'sizes': [{'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': 'XS@1@7',
#       'name': 'XS',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': 'S@2@7',
#       'name': 'S',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': 'M@3@7',
#       'name': 'M',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': 'L@4@7',
#       'name': 'L',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': 'XL@5@7',
#       'name': 'XL',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': 'XXL@6@7',
#       'name': 'XXL',
#       'selectable': True,
#       'selected': False}]},
#    {'id': 'Size Filter Category_Ladies/Men tum size',
#     'label': 'Waist Size',
#     'sizes': [{'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '24@1@3',
#       'name': '24',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '25@2@3',
#       'name': '25',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '26@3@3',
#       'name': '26',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '27@4@3',
#       'name': '27',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '28@5@3',
#       'name': '28',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '29@6@3',
#       'name': '29',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '30@7@3',
#       'name': '30',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '31@8@3',
#       'name': '31',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '32@9@3',
#       'name': '32',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '33@10@3',
#       'name': '33',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '34@11@3',
#       'name': '34',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '36@12@3',
#       'name': '36',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '38@13@3',
#       'name': '38',
#       'selectable': True,
#       'selected': False}]},
#    {'id': 'Size Filter Category_Ladies shoes',
#     'label': "Women's Shoes",
#     'sizes': [{'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '4.5@1@5',
#       'name': '4.5',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '5.5@2@5',
#       'name': '5.5',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '6@3@5',
#       'name': '6',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '7@4@5',
#       'name': '7',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '8@5@5',
#       'name': '8',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '8.5@6@5',
#       'name': '8.5',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '9.5@7@5',
#       'name': '9.5',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '10@8@5',
#       'name': '10',
#       'selectable': True,
#       'selected': False}]},
#    {'id': 'Size Filter Category_Bra',
#     'label': 'Bra Size',
#     'sizes': [{'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '30A@1@0',
#       'name': '30A',
#       'selectable': False,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '32A@2@0',
#       'name': '32A',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '34A@3@0',
#       'name': '34A',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '36A@4@0',
#       'name': '36A',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '38A@5@0',
#       'name': '38A',
#       'selectable': False,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '40A@6@0',
#       'name': '40A',
#       'selectable': False,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '30B@7@0',
#       'name': '30B',
#       'selectable': False,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '32B@8@0',
#       'name': '32B',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '34B@9@0',
#       'name': '34B',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '36B@10@0',
#       'name': '36B',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '38B@11@0',
#       'name': '38B',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '40B@12@0',
#       'name': '40B',
#       'selectable': False,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '42B@13@0',
#       'name': '42B',
#       'selectable': False,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '30C@14@0',
#       'name': '30C',
#       'selectable': False,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '32C@15@0',
#       'name': '32C',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '34C@16@0',
#       'name': '34C',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '36C@17@0',
#       'name': '36C',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '38C@18@0',
#       'name': '38C',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '40C@19@0',
#       'name': '40C',
#       'selectable': False,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '42C@20@0',
#       'name': '42C',
#       'selectable': False,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '32D@21@0',
#       'name': '32D',
#       'selectable': False,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '34D@22@0',
#       'name': '34D',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '36D@23@0',
#       'name': '36D',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '38D@24@0',
#       'name': '38D',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '40D@25@0',
#       'name': '40D',
#       'selectable': False,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '42D@26@0',
#       'name': '42D',
#       'selectable': False,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '34E@27@0',
#       'name': '34E',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '36E@28@0',
#       'name': '36E',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '38E@29@0',
#       'name': '38E',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '34F@30@0',
#       'name': '34F',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '36F@31@0',
#       'name': '36F',
#       'selectable': True,
#       'selected': False}]},
#    {'id': 'Size Filter Category_Kids shoes & socks',
#     'label': "Kids' Shoes",
#     'sizes': [{'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '0@1@2',
#       'name': '0',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '1@2@2',
#       'name': '1',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '2@3@2',
#       'name': '2',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '3@4@2',
#       'name': '3',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '4@5@2',
#       'name': '4',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '5@6@2',
#       'name': '5',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '6@7@2',
#       'name': '6',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '7@8@2',
#       'name': '7',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '7.5@9@2',
#       'name': '7.5',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '8.5@10@2',
#       'name': '8.5',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '9.5@11@2',
#       'name': '9.5',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '10.5@12@2',
#       'name': '10.5',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '12@13@2',
#       'name': '12',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '13@14@2',
#       'name': '13',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '1@15@2',
#       'name': '1',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '1.5@16@2',
#       'name': '1.5',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '2@17@2',
#       'name': '2',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '3@18@2',
#       'name': '3',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '3.5@19@2',
#       'name': '3.5',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '4.5@20@2',
#       'name': '4.5',
#       'selectable': False,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '5@21@2',
#       'name': '5',
#       'selectable': False,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '5.5@22@2',
#       'name': '5.5',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '6@23@2',
#       'name': '6',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '7@24@2',
#       'name': '7',
#       'selectable': False,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '8@25@2',
#       'name': '8',
#       'selectable': False,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '9@26@2',
#       'name': '9',
#       'selectable': False,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '10@27@2',
#       'name': '10',
#       'selectable': False,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '11@28@2',
#       'name': '11',
#       'selectable': False,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '12@29@2',
#       'name': '12',
#       'selectable': False,
#       'selected': False}]},
#    {'id': 'Size Filter Category_Men shoes',
#     'label': "Men's Shoes",
#     'sizes': [{'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '7.5@1@6',
#       'name': '7.5',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '8.5@2@6',
#       'name': '8.5',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '9@3@6',
#       'name': '9',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '10@4@6',
#       'name': '10',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '10.5@5@6',
#       'name': '10.5',
#       'selectable': True,
#       'selected': False},
#      {'colour': {'blue': 0, 'green': 0, 'red': 0},
#       'id': '11.5@6@6',
#       'name': '11.5',
#       'selectable': True,
#       'selected': False}]}],
#   'sizeFilterState': 'MULTIPLE',
#   'sizes': []},
#  'pagination': {'count': 4668,
#   'link': '<http://api.hm.com/v2/US/en/products/display?categories=sale&concealCategories=true&pageSize=60&page=2&deviceType=DESKTOP>; rel="next", <http://api.hm.com/v2/US/en/products/display?categories=sale&concealCategories=true&pageSize=60&page=78&deviceType=DESKTOP>; rel="last"',
#   'page': 1,
#   'pageSize': 60},
#  'recommendations': [],
#  'searchInfo': {'categories': ['/sale'], 'suggestions': []},
#  'trackingInfo': {'canonicalLink': 'http://www.hm.com/us/products/sale',
#   'metricCategoryID': 'Sale : View All',
#   'metricPageID': 'SALE_VIEWALL'}}

# %%
articles = data['displayArticles']

# %%
names = []
for article in articles:
    name = article['name']
    names.append(name)
print(names)
print("Number of displayed articles:",len(names))
# Out:
# ['Jersey Top', 'Jersey Top', 'Super-slim-fit Pants', 'Super-slim-fit Pants', 'V-neck Blouse', 'Jersey Top', 'Super-slim-fit Pants', 'Pajama Tank Top and Shorts', 'Fine-knit Cardigan', 'Lyocell Utility Shirt', 'Slim-fit Treggings', 'Cotton Blouse', 'Printed Sweatshirt', 'Slim-fit Treggings', 'Short-sleeved Shirt Slim fit', 'Super-slim-fit Pants', 'Slub Jersey T-shirt', 'Top with Lace Yoke', 'Sweatpants', 'Lyocell Jacket', 'Short-sleeved Shirt Slim fit', 'MAMA Jersey Top', 'Sleeveless Blouse', 'Top with Lace Details', 'Wide-cut Top', '2-pack Push-up Bras', 'Off-the-shoulder Top', 'Jersey Biker Leggings', 'Hooded V-neck Sweatshirt', 'Denim Shorts', 'T-shirt with Printed Design', 'Top with Lace', 'Dress and Leggings', 'Short-sleeved Top', 'Slim-fit Leggings', 'V-neck Jersey Top', 'Lyocell Top', 'Pull-on Pants', 'Short Jersey Tank Top', 'Skinny High Jeans', 'Short-sleeved Top', 'Jersey Top', 'Slim-fit Leggings', 'V-neck T-shirt Slim fit', 'Single-button Jersey Blazer', 'Sweatpants Skinny fit', 'Striped Jersey Top', 'T-shirt with Printed Design', '3-pack Cotton-blend Briefs', 'Fine-knit Cardigan', 'Denim Skirt', 'Pajama Shorts and Top', 'MAMA Jersey Top', 'Cotton Shirt Regular fit', 'Chinos Skinny fit', 'Short T-shirt', 'Denim Joggers', 'T-shirt with Motif', 'Hooded Jacket', 'Hooded Jacket']
# Number of displayed articles: 60

# %% [markdown]
# ## URLs

# %% [markdown]
# ### What is the URL for data about on-sale men's clothing?

# %%
url_men = ("http://api.hm.com/v2/us/en/products/"+\
           "display?categories=sale%2Fmen&concealCategories=true&pageSize=60&page=1&deviceType=DESKTOP")

# %% [markdown]
# ### What is the URL for data about on-sale women's clothing?

# %%
url_women = ("http://api.hm.com/v2/us/en/products/"+\
             "display?categories=sale%2Fladies&concealCategories=true&pageSize=60&page=1&deviceType=DESKTOP")

# %% [markdown]
# ### What is the URL for data about on-sale women's tops?

# %%
url_women_top = ("http://api.hm.com/v2/us/en/products/display?"+\
                 "categories=sale%2Fladies%2Ftops&concealCategories=true&pageSize=60&page=1&deviceType=DESKTOP")

# %% [markdown]
# ### What changes about the url based on what you're looking for?

# %%
# the "categories" criterium

# %% [markdown]
# ## Request on-sale women's tops.
#
# ### How many results do you get?

# %%
response = requests.get(url_women_top)
data = response.json()

# %%
articles = data['displayArticles']
names = []
for article in articles:
    name = article['name']
    names.append(name)
print("Number of found articles",len(names))
# Out:
# Number of found articles 60

# %% [markdown]
# ### How many total results are there? How do you change the URL to get more?
#
# There are a few ways to change the URL to: there is one very easy way and one a-little-difficult way.

# %%
#increase pageSize in the URL
names = []
page_number = 1

# %%
while True:
    url_women_top = ("http://api.hm.com/v2/us/en/products/display?"+\
                    "categories=sale%2Fladies%2Ftops&concealCategories=true&pageSize=60&page="\
                    +str(page_number)+"&deviceType=DESKTOP")
    response = requests.get(url_women_top)
    data = response.json()
    if data['displayArticles']:
        articles = data['displayArticles']
        for article in articles:
            name = article['name']
            names.append(name)
            print(name)
        page_number += 1
    else:
        break
# Out:
# Jersey Top
# Jersey Top
# Jersey Top
# T-shirt with Printed Design
# Striped Jersey Top
# T-shirt with Printed Design
# T-shirt with Printed Design
# Short-sleeved Top
# Boat-neck Top
# Pleated Top
# Pleated Top
# Top with Lace Details
# Top with Lace
# Top with Lace Details
# Long-sleeved Top
# Long-sleeved Top
# Long-sleeved Top
# Top with Lace
# Long-sleeved Top
# Long-sleeved Jersey Top
# Top with Lace Yoke
# Lyocell Top
# Short Jersey Tank Top
# Lyocell Top
# Polo Shirt
# Lyocell Jersey Tank Top
# Lyocell Jersey Tank Top
# Slub Jersey Top
# Slub Jersey Top
# Slub Jersey Top
# Mock-turtleneck Top
# Ribbed Top
# Ribbed Top
# Wide-cut Top
# Off-the-shoulder Top
# Short-sleeved Top
# V-neck Jersey Top
# Short-sleeved Top
# Jersey Top
# Short T-shirt
# T-shirt with Motif
# Blouce with Lace Yoke
# Crêped Top
# V-neck Sweater
# Ribbed Tank Top
# Cotton-blend T-shirt
# Tank Top with Lacing
# Short T-shirt
# Nepped T-shirt
# Crêped Camisole Top
# Linen Scoop-neck Top
# T-shirt with Motif
# Long-sleeved Top
# Jersey Top
# Nepped T-shirt
# Draped Top
# Short Top
# Short-sleeved Top
# Cotton Jersey T-shirt
# T-shirt with Printed Design
# Printed Jersey Bodysuit
# V-neck Jersey Top
# T-shirt with Motif
# T-shirt with Motif
# Jersey Camisole Top
# Top with Printed Design
# Ruffled Top
# V-neck Jersey Top
# Long T-shirt
# Bustier
# Wide T-shirt with Chest Pocket
# Jersey Top with Ruffles
# V-neck Jersey Top
# Jersey T-shirt
# Wide T-shirt with Chest Pocket
# T-shirt with Printed Design
# Long Linen-blend T-shirt
# V-neck Jersey Top
# Long-sleeved Jersey Top
# Jersey Top
# Metallic Bodysuit
# T-shirt with Motif
# Jersey Bodysuit
# Slub Jersey Top
# Tank Top with Lacing
# Camisole Top with Knot
# Short Top
# Bustier
# Crêped Camisole Top
# Sleeveless Jersey Top
# Jersey Top
# Ribbed Tank Top
# Slub Jersey Top
# Linen Scoop-neck Top
# Ribbed Jersey Top
# Beaded Camisole Top
# Cotton T-shirt
# Top with Woven Front Section
# Ribbed Jersey Top
# Boat-neck Top
# Linen Jersey Top
# Velour Camisole Top
# Embroidered Mesh Top
# Short Top
# Wide-cut T-shirt
# Lace Top
# Short Top
# Draped Top
# Draped Top
# Jersey Crêpe Top
# V-neck Jersey Top
# Ribbed Camisole Top
# Lace Top
# Long-sleeved Bodysuit
# Fine-knit Top
# Top with Printed Design
# Short-sleeved Top
# Long-sleeved Bodysuit
# Camisole Top with Flounce
# Jersey Top
# Wide-cut T-shirt
# Cotton Jersey T-shirt
# Short Top
# Fine-knit Top
# Top with Lace Detail
# Lace-trimmed Cotton Tank Top
# Ribbed Jersey Top
# Glittery Bandeau Top
# Hemstitch-embroidered Top
# T-shirt with Printed Design
# Crushed-velvet Top
# Jersey Camisole Top
# Long-sleeved Lace Top
# Long-sleeved Top
# Jersey Top
# Short-sleeved Top
# Uni Tee
# Wide-cut T-shirt
# Short Jersey Top
# Crushed-velvet Camisole Top
# Sleeveless Jersey Top
# One-shoulder Top
# Fine-knit Top
# Ruffled Top
# Sleeveless Jersey Top
# V-neck Short-sleeved Sweater
# Lace Top
# Jersey Top
# Long-sleeved Jersey Top
# T-shirt with Motif
# Mock-turtleneck Bodysuit
# Short Printed Jersey Top
# Wide-cut Camisole Top
# V-neck Satin Camisole Top
# Camisole Top with Mesh Detail
# Off-the-shoulder Top
# Wide-cut T-shirt
# T-shirt with Printed Design
# V-neck Jersey Top
# One-shoulder Top
# Cotton T-shirt
# Wide-cut Camisole Top
# Long-sleeved Bodysuit
# Fine-knit Turtleneck Top
# V-neck Top
# Short Top with Elastic
# Jersey Top
# Short Mesh Top
# Ribbed Top
# V-neck Top
# Slub Jersey Top
# Long-sleeved Lace Top
# Jersey Camisole Top
# Fine-knit Camisole Top
# Tulle Top
# V-neck Camisole Top
# One-shoulder Top
# Mock-turtleneck Top
# Silk-blend Top
# Short Sweatshirt
# Lace Top
# Fine-knit Top
# Fine-knit Camisole Top
# Wide-cut Camisole Top
# T-shirt with Motif
# Long-sleeved Linen Top
# Jersey Top
# Polo Shirt
# Long-sleeved Linen Top
# Uni Tee
# Polo Shirt
# Fitted Sweater
# Ruffled Top
# Fine-knit Turtleneck Top
# Ribbed Sweater
# T-shirt with Printed Design
# Wrap-front Sweater
# Tube Top
# Long-sleeved Jersey Top
# Ribbed Sweater
# Long-sleeved Linen Top
# Jersey Top with Lace
# V-neck Top
# Lace Top
# Bustier
# Crêped Jersey Top
# Jersey Top
# Long-sleeved Jersey Top
# Loose-knit Top
# Ribbed Camisole Top
# Short Top
# Bustier
# Wide-cut T-shirt
# Short Lace Top
# Pleated Top
# Double-layer Camisole Top
# Airy Jersey Top
# Jersey Camisole Top with Lace
# Jersey Top
# Ribbed Top
# Jersey Top
# Short Top with Lacing
# Glittery Bustier
# Sleeveless Top with Lace
# Long-sleeved Linen Top
# Jersey Top
# Flounced Crop Top
# Mock-turtleneck Top
# Crushed-velvet Top
# Loose-knit Top
# Mock-turtleneck Top
# Short Top
# V-neck Camisole Top
# Jersey Top
# Long-sleeved Top
# Crushed-velvet Camisole Top
# Ribbed Top
# Sleeveless Top with Lace
# Wide-cut Camisole Top
# Long-sleeved Top
# Silk-blend Top
# Jersey Top
# Draped Top
# Ribbed Top
# Long-sleeved Jersey Top
# Jersey Top
# Sequined Bustier
# Ribbed Jersey Top
# Fitted Sweater
# Short Top
# Ribbed Top
# Cupro-blend Top
# Velvet Camisole Top
# Ribbed Sweater
# Off-the-shoulder Top
# Top with Smocking
# Long-sleeved T-shirt
# Linen-blend Top
# Fitted Lace Top
# Velour T-shirt
# Pleated Top
# Ribbed Top
# Rib-knit Sweater
# Glittery Bustier
# Long-sleeved Top
# Lace Camisole Top
# Jersey Top
# Short Top
# Embellished Chiffon Top
# Short Ruffled Top
# Handkerchief Top
# Velour Camisole Top
# T-shirt with Printed Design
# Jersey Top with Printed Design
# Velvet Camisole Top
# Lyocell Top
# Camisole Top with Mesh Detail
# Beaded Lace Top
# Jersey Top
# Long-sleeved Jersey Top
# Lyocell Top
# Mesh Ruffled Top
# Long-sleeved Jersey Top
# Sleeveless Top
# Sleeveless Turtleneck Sweater
# Ribbed Top
# One-shoulder Top
# Jersey Tank Top
# Pointelle Top
# Velour Top
# V-neck Camisole Top
# Jersey Top
# Ribbed Top
# Mock-turtleneck Top
# Short Satin Top
# Off-the-shoulder Top
# Sequin-embroidered Bustier
# Top with Lacing
# Glittery Top
# Tank Top with Ties
# Chiffon Top
# V-neck Top
# Sequined Tank Top
# Ribbed Top
# V-neck Camisole Top
# Top with Open Back
# Long-sleeved Lace Top
# V-neck Camisole Top
# Velour Top
# Short Top
# Sleeveless Top
# Ribbed Top
# Long-sleeved Top
# Jersey Top
# Ribbed Jersey Top
# Draped Top
# Jersey Top
# Short Glittery Top
# Velour Top
# Crushed-velvet Camisole Top
# Fitted Jersey Top
# Glittery Camisole Top
# Ruffled Top
# Halterneck Top
# Long Jersey Top
# Satin Peplum Top
# Long-sleeved Jersey Top
# Fine-knit Glittery Top
# Ribbed Jersey Top
# Ribbed Top
# V-neck Bodysuit
# Jersey Top with Lace
# Ribbed Top
# Sequined Top
# Short Top with Lacing
# Long-sleeved Jersey Top
# Ribbed Mock Turtleneck Sweater
# Glittery Camisole Top
# Draped Jersey Top
# V-neck Top
# Lace Top
# Flounced Chiffon Camisole Top
# Sequined Camisole Top
# Cropped Camisole Top
# Camisole Top
# Ribbed Sweater
# Glittery Top

# %%
len(names)
# Out:
# 347

# %% [markdown]
# ### Download all on-sale women's tops and save them to a CSV.
#
# I want this CSV to include
#
# - Name
# - Product code/number
# - Old price
# - On-sale price
# - Item's URL

# %%
products = []
page_number = 1

while True:
    url_women_top = ("http://api.hm.com/v2/us/en/products/display?"+\
                    "categories=sale%2Fladies%2Ftops&concealCategories=true&pageSize=60&page="\
                    +str(page_number)+"&deviceType=DESKTOP")
    response = requests.get(url_women_top)
    data = response.json()
    if data['displayArticles']:
        articles = data['displayArticles']
        for article in articles:
            current = {}
            current['Name'] = article['name']
            current['Product code'] = article['productNumber']
            current['Old price'] = article['priceInfo']['formattedOldPrice']
            current['New price'] = article['priceInfo']['formattedPrice']
            current['URL'] = article['webUrl']
            products.append(current)
        page_number += 1
    else:
        break

# %%
df = pd.DataFrame(products)
df.to_csv('HM_prices.csv', index=False)

# %% [markdown]
# ## Analyzing on-sale items
#
# ### Read in the on-sale CSV and make sure the data looks right

# %%
df = df.from_csv('HM_prices.csv')
df
# Out:
#                                New price Old price  Product code  \
# Name
# Jersey Top                            $5    $12.99         60133
# Jersey Top                            $5    $12.99         60133
# Jersey Top                         $5.99    $12.99         68934
# T-shirt with Printed Design        $5.99    $12.99         63019
# Striped Jersey Top                 $9.99    $14.99         64644
# T-shirt with Printed Design        $5.99    $12.99         63019
# T-shirt with Printed Design        $5.99    $12.99         63019
# Short-sleeved Top                  $6.99     $9.99         65274
# Boat-neck Top                      $7.99    $14.99         38259
# Pleated Top                        $9.99    $17.99         67571
# Pleated Top                        $9.99    $17.99         67571
# Top with Lace Details                 $7    $14.99         67739
# Top with Lace                     $12.99    $24.99         68451
# Top with Lace Details                 $7    $14.99         67739
# Long-sleeved Top                   $5.99    $12.99         62235
# Long-sleeved Top                   $5.99    $12.99         62235
# Long-sleeved Top                   $5.99    $12.99         62235
# Top with Lace                     $12.99    $24.99         68451
# Long-sleeved Top                   $5.99    $12.99         62235
# Long-sleeved Jersey Top            $9.99    $17.99         54285
# Top with Lace Yoke                 $5.99     $9.99         68429
# Lyocell Top                        $7.99    $14.99         67584
# Short Jersey Tank Top              $2.99     $4.99         69443
# Lyocell Top                        $7.99    $14.99         67584
# Polo Shirt                         $5.99    $12.99         43558
# Lyocell Jersey Tank Top            $6.99    $12.99         70462
# Lyocell Jersey Tank Top            $6.99    $12.99         70462
# Slub Jersey Top                    $5.99    $12.99         54630
# Slub Jersey Top                    $7.99    $17.99         43522
# Slub Jersey Top                    $7.99    $17.99         43522
# ...                                  ...       ...           ...
# Short Glittery Top                $14.99    $29.99         53308
# Velour Top                        $14.99    $24.99         69616
# Crushed-velvet Camisole Top       $24.99    $34.99         69676
# Fitted Jersey Top                 $12.99    $24.99         88680
# Glittery Camisole Top             $17.99    $24.99         58956
# Ruffled Top                       $17.99    $29.99         59269
# Halterneck Top                    $19.99    $34.99         53502
# Long Jersey Top                   $12.99    $24.99         57920
# Satin Peplum Top                  $24.99    $34.99         56723
# Long-sleeved Jersey Top           $12.99    $17.99         54285
# Fine-knit Glittery Top            $14.99    $24.99         44550
# Ribbed Jersey Top                  $7.99    $17.99         56300
# Ribbed Top                           $10    $17.95         76777
# V-neck Bodysuit                   $17.99    $24.99         60992
# Jersey Top with Lace              $14.99    $24.99         39074
# Ribbed Top                         $9.99    $17.99         56889
# Sequined Top                      $29.99    $49.99         58474
# Short Top with Lacing             $17.99    $29.99         62105
# Long-sleeved Jersey Top           $12.99    $17.99         54285
# Ribbed Mock Turtleneck Sweater    $19.99    $34.99         55016
# Glittery Camisole Top             $17.99    $24.99         58956
# Draped Jersey Top                  $7.99    $17.99         55302
# V-neck Top                        $17.99    $29.99         50693
# Lace Top                          $12.99    $24.95         30892
# Flounced Chiffon Camisole Top     $14.99    $29.99         60809
# Sequined Camisole Top             $29.99    $49.99         55491
# Cropped Camisole Top              $14.99    $29.99         45952
# Camisole Top                      $17.99    $34.99         41726
# Ribbed Sweater                     $9.99    $12.99         59865
# Glittery Top                      $34.99    $49.99         37042
#
#                                                                               URL
# Name
# Jersey Top                      http://www.hm.com/us/product/60133?article=601...
# Jersey Top                      http://www.hm.com/us/product/60133?article=601...
# Jersey Top                      http://www.hm.com/us/product/68934?article=689...
# T-shirt with Printed Design     http://www.hm.com/us/product/63019?article=630...
# Striped Jersey Top              http://www.hm.com/us/product/64644?article=646...
# T-shirt with Printed Design     http://www.hm.com/us/product/63019?article=630...
# T-shirt with Printed Design     http://www.hm.com/us/product/63019?article=630...
# Short-sleeved Top               http://www.hm.com/us/product/65274?article=652...
# Boat-neck Top                   http://www.hm.com/us/product/38259?article=382...
# Pleated Top                     http://www.hm.com/us/product/67571?article=675...
# Pleated Top                     http://www.hm.com/us/product/67571?article=675...
# Top with Lace Details           http://www.hm.com/us/product/67739?article=677...
# Top with Lace                   http://www.hm.com/us/product/68451?article=684...
# Top with Lace Details           http://www.hm.com/us/product/67739?article=677...
# Long-sleeved Top                http://www.hm.com/us/product/62235?article=622...
# Long-sleeved Top                http://www.hm.com/us/product/62235?article=622...
# Long-sleeved Top                http://www.hm.com/us/product/62235?article=622...
# Top with Lace                   http://www.hm.com/us/product/68451?article=684...
# Long-sleeved Top                http://www.hm.com/us/product/62235?article=622...
# Long-sleeved Jersey Top         http://www.hm.com/us/product/54285?article=542...
# Top with Lace Yoke              http://www.hm.com/us/product/68429?article=684...
# Lyocell Top                     http://www.hm.com/us/product/67584?article=675...
# Short Jersey Tank Top           http://www.hm.com/us/product/69443?article=694...
# Lyocell Top                     http://www.hm.com/us/product/67584?article=675...
# Polo Shirt                      http://www.hm.com/us/product/43558?article=435...
# Lyocell Jersey Tank Top         http://www.hm.com/us/product/70462?article=704...
# Lyocell Jersey Tank Top         http://www.hm.com/us/product/70462?article=704...
# Slub Jersey Top                 http://www.hm.com/us/product/54630?article=546...
# Slub Jersey Top                 http://www.hm.com/us/product/43522?article=435...
# Slub Jersey Top                 http://www.hm.com/us/product/43522?article=435...
# ...                                                                           ...
# Short Glittery Top              http://www.hm.com/us/product/53308?article=533...
# Velour Top                      http://www.hm.com/us/product/69616?article=696...
# Crushed-velvet Camisole Top     http://www.hm.com/us/product/69676?article=696...
# Fitted Jersey Top               http://www.hm.com/us/product/88680?article=886...
# Glittery Camisole Top           http://www.hm.com/us/product/58956?article=589...
# Ruffled Top                     http://www.hm.com/us/product/59269?article=592...
# Halterneck Top                  http://www.hm.com/us/product/53502?article=535...
# Long Jersey Top                 http://www.hm.com/us/product/57920?article=579...
# Satin Peplum Top                http://www.hm.com/us/product/56723?article=567...
# Long-sleeved Jersey Top         http://www.hm.com/us/product/54285?article=542...
# Fine-knit Glittery Top          http://www.hm.com/us/product/44550?article=445...
# Ribbed Jersey Top               http://www.hm.com/us/product/56300?article=563...
# Ribbed Top                      http://www.hm.com/us/product/76777?article=767...
# V-neck Bodysuit                 http://www.hm.com/us/product/60992?article=609...
# Jersey Top with Lace            http://www.hm.com/us/product/39074?article=390...
# Ribbed Top                      http://www.hm.com/us/product/56889?article=568...
# Sequined Top                    http://www.hm.com/us/product/58474?article=584...
# Short Top with Lacing           http://www.hm.com/us/product/62105?article=621...
# Long-sleeved Jersey Top         http://www.hm.com/us/product/54285?article=542...
# Ribbed Mock Turtleneck Sweater  http://www.hm.com/us/product/55016?article=550...
# Glittery Camisole Top           http://www.hm.com/us/product/58956?article=589...
# Draped Jersey Top               http://www.hm.com/us/product/55302?article=553...
# V-neck Top                      http://www.hm.com/us/product/50693?article=506...
# Lace Top                        http://www.hm.com/us/product/30892?article=308...
# Flounced Chiffon Camisole Top   http://www.hm.com/us/product/60809?article=608...
# Sequined Camisole Top           http://www.hm.com/us/product/55491?article=554...
# Cropped Camisole Top            http://www.hm.com/us/product/45952?article=459...
# Camisole Top                    http://www.hm.com/us/product/41726?article=417...
# Ribbed Sweater                  http://www.hm.com/us/product/59865?article=598...
# Glittery Top                    http://www.hm.com/us/product/37042?article=370...
#
# [347 rows x 4 columns]

# %% [markdown]
# ### Convert the prices to numbers, if you haven't already

# %%
df['New price'] = df['New price'].str.replace('$', '')
df['Old price'] = df['Old price'].str.replace('$', '')

# %% [markdown]
# ### What is the average on-sale price of a women's top? Make a histogram, too, please.

# %%
# %matplotlib inline
average_price = df['New price'].astype(float)
print("The average on-sale price is $",round(average_price.mean(),2))
average_price.hist()
# Out:
# The average on-sale price is $ 11.3

# %% [markdown]
# ### What is the average discount between full price and on sale? Histogram too, please.

# %%
discount_dollar = df['Old price'].astype(float)-average_price
print("The average discount is $",round(discount_dollar.mean(),2))
discount_dollar.hist()
# Out:
# The average discount is $ 8.57

# %% [markdown]
# ### What is the average discount as a percentage of the full price? Histogram too, please.

# %%
discount_percentage = discount_dollar/df['Old price'].astype(float)*100
print("The average discount is",round(discount_percentage.mean(),2),"per cent")
discount_percentage.hist()
# Out:
# The average discount is 42.37 per cent

# %% [markdown]
# ## Shopping the sales
#
# ### How many items are over 50% off?

# %%
print(df[discount_percentage>50]['Product code'].count(),"items are over 50% off")
# Out:
# 83 items are over 50% off

# %% [markdown]
# ### Display all items above 50% off.
#
# Pandas doesn't want to show you every row. Change its settings so it will display up to **200 rows of content.**

# %%
pd.options.display.max_rows = 200
df[discount_percentage>50]
# Out:
#                               New price Old price  Product code  \
# Name
# Jersey Top                            5     12.99         60133
# Jersey Top                            5     12.99         60133
# Jersey Top                         5.99     12.99         68934
# T-shirt with Printed Design        5.99     12.99         63019
# T-shirt with Printed Design        5.99     12.99         63019
# T-shirt with Printed Design        5.99     12.99         63019
# Top with Lace Details                 7     14.99         67739
# Top with Lace Details                 7     14.99         67739
# Long-sleeved Top                   5.99     12.99         62235
# Long-sleeved Top                   5.99     12.99         62235
# Long-sleeved Top                   5.99     12.99         62235
# Long-sleeved Top                   5.99     12.99         62235
# Polo Shirt                         5.99     12.99         43558
# Slub Jersey Top                    5.99     12.99         54630
# Slub Jersey Top                    7.99     17.99         43522
# Slub Jersey Top                    7.99     17.99         43522
# Ribbed Top                         7.99     17.99         65943
# Wide-cut Top                       7.99     17.99         69910
# Short-sleeved Top                  5.99     12.99         62216
# Blouce with Lace Yoke             14.99     29.99         68183
# Nepped T-shirt                     7.99     17.99         67360
# Crêped Camisole Top                   7     17.99         65300
# Long-sleeved Top                   6.99     14.99         61473
# Jersey Top                         5.99     12.99         68161
# Nepped T-shirt                     7.99     17.99         67360
# Top with Printed Design            5.99     12.99         70360
# Jersey T-shirt                     5.99     12.99         62231
# V-neck Jersey Top                  5.99     14.99         89119
# Long-sleeved Jersey Top            5.99     12.99         38141
# Slub Jersey Top                    5.99     12.99         54630
# Crêped Camisole Top                   7     17.99         65300
# Jersey Top                         5.99     14.99         44402
# Slub Jersey Top                    5.99     12.99         54630
# Ribbed Jersey Top                  5.99     12.99         70480
# Beaded Camisole Top                7.99     17.99         47468
# Ribbed Jersey Top                  5.99     12.99         70480
# Top with Printed Design            5.99     12.99         70360
# Jersey Top                         5.99     12.99         64688
# Fine-knit Top                      7.99     17.99         65484
# Ribbed Jersey Top                  5.99     12.99         70480
# Long-sleeved Top                   6.99     14.99         61473
# V-neck Short-sleeved Sweater       7.99     17.99         64045
# Long-sleeved Jersey Top            5.99     12.99         65001
# One-shoulder Top                   5.99     12.99         49881
# Fine-knit Turtleneck Top           7.99     17.99         67189
# V-neck Top                         7.99     17.99         69690
# Ribbed Top                        14.99     29.99         67941
# Fine-knit Camisole Top            12.99     29.99         67259
# Tulle Top                         19.99     39.99         68538
# One-shoulder Top                   7.99     17.99         67836
# Fine-knit Camisole Top            12.99     29.99         67259
# Fitted Sweater                     9.99     29.99         63533
# Tube Top                              4      9.95         26972
# Jersey Top with Lace               9.99     19.99         68149
# V-neck Top                         7.99     17.99         69690
# Bustier                           14.99     29.99         60791
# Crêped Jersey Top                 14.99     29.99         68689
# Ribbed Camisole Top                5.99     12.99         66728
# Bustier                           14.99     29.99         60791
# Short Lace Top                    14.99     29.99         63545
# Ribbed Top                        14.99     29.99         67941
# Draped Top                         9.99     19.99         61712
# Ribbed Top                         9.99     19.99         56148
# Sequined Bustier                  17.99     39.99         58123
# Ribbed Jersey Top                  7.99     17.99         56300
# Fitted Sweater                     9.99     29.99         63533
# Ribbed Top                        12.99     34.99         58201
# Ribbed Top                        14.99     34.99         57946
# Long-sleeved Jersey Top           14.99     29.99         59142
# One-shoulder Top                   7.99     17.99         67836
# V-neck Camisole Top               19.99     39.99         55497
# Ribbed Top                         9.99     19.99         56148
# Glittery Top                      19.99     39.99         61034
# Chiffon Top                       14.99     39.99         82397
# V-neck Top                        12.99     29.99         46814
# V-neck Camisole Top               19.99     39.99         55497
# Sleeveless Top                    14.99     29.99         51196
# Draped Top                         9.99     19.99         61712
# Short Glittery Top                14.99     29.99         53308
# Ribbed Jersey Top                  7.99     17.99         56300
# Draped Jersey Top                  7.99     17.99         55302
# Flounced Chiffon Camisole Top     14.99     29.99         60809
# Cropped Camisole Top              14.99     29.99         45952
#
#                                                                              URL
# Name
# Jersey Top                     http://www.hm.com/us/product/60133?article=601...
# Jersey Top                     http://www.hm.com/us/product/60133?article=601...
# Jersey Top                     http://www.hm.com/us/product/68934?article=689...
# T-shirt with Printed Design    http://www.hm.com/us/product/63019?article=630...
# T-shirt with Printed Design    http://www.hm.com/us/product/63019?article=630...
# T-shirt with Printed Design    http://www.hm.com/us/product/63019?article=630...
# Top with Lace Details          http://www.hm.com/us/product/67739?article=677...
# Top with Lace Details          http://www.hm.com/us/product/67739?article=677...
# Long-sleeved Top               http://www.hm.com/us/product/62235?article=622...
# Long-sleeved Top               http://www.hm.com/us/product/62235?article=622...
# Long-sleeved Top               http://www.hm.com/us/product/62235?article=622...
# Long-sleeved Top               http://www.hm.com/us/product/62235?article=622...
# Polo Shirt                     http://www.hm.com/us/product/43558?article=435...
# Slub Jersey Top                http://www.hm.com/us/product/54630?article=546...
# Slub Jersey Top                http://www.hm.com/us/product/43522?article=435...
# Slub Jersey Top                http://www.hm.com/us/product/43522?article=435...
# Ribbed Top                     http://www.hm.com/us/product/65943?article=659...
# Wide-cut Top                   http://www.hm.com/us/product/69910?article=699...
# Short-sleeved Top              http://www.hm.com/us/product/62216?article=622...
# Blouce with Lace Yoke          http://www.hm.com/us/product/68183?article=681...
# Nepped T-shirt                 http://www.hm.com/us/product/67360?article=673...
# Crêped Camisole Top            http://www.hm.com/us/product/65300?article=653...
# Long-sleeved Top               http://www.hm.com/us/product/61473?article=614...
# Jersey Top                     http://www.hm.com/us/product/68161?article=681...
# Nepped T-shirt                 http://www.hm.com/us/product/67360?article=673...
# Top with Printed Design        http://www.hm.com/us/product/70360?article=703...
# Jersey T-shirt                 http://www.hm.com/us/product/62231?article=622...
# V-neck Jersey Top              http://www.hm.com/us/product/89119?article=891...
# Long-sleeved Jersey Top        http://www.hm.com/us/product/38141?article=381...
# Slub Jersey Top                http://www.hm.com/us/product/54630?article=546...
# Crêped Camisole Top            http://www.hm.com/us/product/65300?article=653...
# Jersey Top                     http://www.hm.com/us/product/44402?article=444...
# Slub Jersey Top                http://www.hm.com/us/product/54630?article=546...
# Ribbed Jersey Top              http://www.hm.com/us/product/70480?article=704...
# Beaded Camisole Top            http://www.hm.com/us/product/47468?article=474...
# Ribbed Jersey Top              http://www.hm.com/us/product/70480?article=704...
# Top with Printed Design        http://www.hm.com/us/product/70360?article=703...
# Jersey Top                     http://www.hm.com/us/product/64688?article=646...
# Fine-knit Top                  http://www.hm.com/us/product/65484?article=654...
# Ribbed Jersey Top              http://www.hm.com/us/product/70480?article=704...
# Long-sleeved Top               http://www.hm.com/us/product/61473?article=614...
# V-neck Short-sleeved Sweater   http://www.hm.com/us/product/64045?article=640...
# Long-sleeved Jersey Top        http://www.hm.com/us/product/65001?article=650...
# One-shoulder Top               http://www.hm.com/us/product/49881?article=498...
# Fine-knit Turtleneck Top       http://www.hm.com/us/product/67189?article=671...
# V-neck Top                     http://www.hm.com/us/product/69690?article=696...
# Ribbed Top                     http://www.hm.com/us/product/67941?article=679...
# Fine-knit Camisole Top         http://www.hm.com/us/product/67259?article=672...
# Tulle Top                      http://www.hm.com/us/product/68538?article=685...
# One-shoulder Top               http://www.hm.com/us/product/67836?article=678...
# Fine-knit Camisole Top         http://www.hm.com/us/product/67259?article=672...
# Fitted Sweater                 http://www.hm.com/us/product/63533?article=635...
# Tube Top                       http://www.hm.com/us/product/26972?article=269...
# Jersey Top with Lace           http://www.hm.com/us/product/68149?article=681...
# V-neck Top                     http://www.hm.com/us/product/69690?article=696...
# Bustier                        http://www.hm.com/us/product/60791?article=607...
# Crêped Jersey Top              http://www.hm.com/us/product/68689?article=686...
# Ribbed Camisole Top            http://www.hm.com/us/product/66728?article=667...
# Bustier                        http://www.hm.com/us/product/60791?article=607...
# Short Lace Top                 http://www.hm.com/us/product/63545?article=635...
# Ribbed Top                     http://www.hm.com/us/product/67941?article=679...
# Draped Top                     http://www.hm.com/us/product/61712?article=617...
# Ribbed Top                     http://www.hm.com/us/product/56148?article=561...
# Sequined Bustier               http://www.hm.com/us/product/58123?article=581...
# Ribbed Jersey Top              http://www.hm.com/us/product/56300?article=563...
# Fitted Sweater                 http://www.hm.com/us/product/63533?article=635...
# Ribbed Top                     http://www.hm.com/us/product/58201?article=582...
# Ribbed Top                     http://www.hm.com/us/product/57946?article=579...
# Long-sleeved Jersey Top        http://www.hm.com/us/product/59142?article=591...
# One-shoulder Top               http://www.hm.com/us/product/67836?article=678...
# V-neck Camisole Top            http://www.hm.com/us/product/55497?article=554...
# Ribbed Top                     http://www.hm.com/us/product/56148?article=561...
# Glittery Top                   http://www.hm.com/us/product/61034?article=610...
# Chiffon Top                    http://www.hm.com/us/product/82397?article=823...
# V-neck Top                     http://www.hm.com/us/product/46814?article=468...
# V-neck Camisole Top            http://www.hm.com/us/product/55497?article=554...
# Sleeveless Top                 http://www.hm.com/us/product/51196?article=511...
# Draped Top                     http://www.hm.com/us/product/61712?article=617...
# Short Glittery Top             http://www.hm.com/us/product/53308?article=533...
# Ribbed Jersey Top              http://www.hm.com/us/product/56300?article=563...
# Draped Jersey Top              http://www.hm.com/us/product/55302?article=553...
# Flounced Chiffon Camisole Top  http://www.hm.com/us/product/60809?article=608...
# Cropped Camisole Top           http://www.hm.com/us/product/45952?article=459...
